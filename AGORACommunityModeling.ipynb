# %% [markdown]
# # Configure KBase Jupyter Dev Environment

# %%
# %run agoracommutil.py
from json import load

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Documents/venv_microbiome_stable/lib/python3.11/site-packages/IPython/core/magics/execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     726     fpath = arg_lst[0]
# --> 727     filename = file_finder(fpath)
#     728 except IndexError as e:
#
# File ~/Documents/venv_microbiome_stable/lib/python3.11/site-packages/IPython/utils/path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'agoracommutil.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('run', 'agoracommutil.py')
#       2 from json import load
#       4 logger = logging.getLogger(__name__)
#
# File ~/Documents/venv_microbiome_stable/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2488, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2486     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2487 with self.builtin_trap:
# -> 2488     result = fn(*args, **kwargs)
#    2490 # The code below prevents the output from being displayed
#    2491 # when using magics with decorator @output_can_be_silenced
#    2492 # when the last Python token in the expression is a ';'.
#    2493 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/venv_microbiome_stable/lib/python3.11/site-packages/IPython/core/magics/execution.py:738, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     736     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     737         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 738     raise Exception(msg) from e
#     739 except TypeError:
#     740     if fpath in sys.meta_path:
#
# Exception: File `'agoracommutil.py'` not found.

# %% [markdown]
# # Loading ASV abundances for all samples

# %%
asv_abundances = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/abundance.json", 'r'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 asv_abundances = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/abundance.json", 'r'))
#
# NameError: name 'load' is not defined

# %% [markdown]
# # Loading metabolomics data

# %%
import pandas as pd
df = pd.read_csv('metabolomics differences.csv')
metabolomics_data = {}
for index, row in df.iterrows():
    metabolomics_data[row["day_diet diff"]] = {}
    for col in df:
        if col != "day_diet diff":
            if col in row:
                metabolomics_data[row["day_diet diff"]][col] = row[col]
util.kbdevutil.save("metabolomics_data", metabolomics_data)

# %% [markdown]
# # Merging models to produce community models for all samples

# %%
import cobra
from cobra import Model, Reaction, Metabolite
asv_abundances = util.kbdevutil.load("asv_abundances")
constraints = {}
biomass_compounds = {}
abundance_by_name = {}
species_reactions = {}
newmodels = {}
biomass_exchange_ids = {}
for sample, abundances in asv_abundances.items():
    print("Processing sample: "+sample)
    community_model = Model(sample,sample)
    constraints = {}
    species_reactions = {}
    biomass_compounds = {}
    abundance_by_name = {}
    biomass_exchange_ids = []
    for asv, abundance in abundances.items():
        print("Processing ASV: "+asv+" with abundance: "+str(abundance)+" in sample "+sample)
        name_array = asv.split(";")
        species_reactions[name_array[0]] = []
        abundance_by_name[name_array[0]] = abundance
        model = cobra.io.read_sbml_model("models/"+asv+'.xml')
        model.objective = "EX_biomass(e)"
        solution = model.optimize()
        print(solution)
        new_metabolites = []
        new_reactions = []
        for met in model.metabolites:
            if met.compartment != "e":
                met.id += "_"+str(name_array[0])
            if met.id not in community_model.metabolites:
                new_metabolites.append(met)
                if "biomass" in met.id:
                    biomass_compounds[name_array[0]] = met.id
        for rxn in model.reactions:
            if rxn.id[0:3] == "EX_":
                if "biomass" in rxn.id:
                    rxn.id += "_"+str(name_array[0])
                    if rxn.id not in biomass_exchange_ids:
                         biomass_exchange_ids.append(rxn.id)
            else:
                rxn.id += "_"+str(name_array[0])
                species_reactions[name_array[0]].append(rxn.id)
            if rxn.id not in community_model.reactions:
                new_reactions.append(rxn)
        # Adding new reactions and compounds to base model
        community_model.add_reactions(new_reactions)
        community_model.add_metabolites(new_metabolites)
    # Create community biomass
    comm_biomass = Metabolite("community_biomass", None, "Community biomass", 0, "c")
    metabolites = {comm_biomass: 1}
    drainmet = {comm_biomass: -1}
    for asv in biomass_compounds:
        met = community_model.metabolites.get_by_id(biomass_compounds[asv])
        metabolites[met] = -1*abundance_by_name[asv]
    comm_biorxn = Reaction(id="bio1", name="bio1", lower_bound=0, upper_bound=100)
    comm_biorxn.add_metabolites(metabolites)
    comm_drain = Reaction(id="EX_community_biomass", name="EX_community_biomass", lower_bound=0, upper_bound=100)
    comm_drain.add_metabolites(drainmet)
    community_model.add_reactions([comm_biorxn,comm_drain])
    for bioex_id in biomass_exchange_ids:
        rxn = community_model.reactions.get_by_id(bioex_id)
        rxn.lower_bound = 0
        rxn.upper_bound = 0
    for bioex_id in biomass_exchange_ids:
        rxn = community_model.reactions.get_by_id(bioex_id)
        rxn.lower_bound = 0
        rxn.upper_bound = 100
        community_model.objective = bioex_id
        solution = community_model.optimize()
        print(bioex_id,solution.objective_value)
        rxn.lower_bound = 0
        rxn.upper_bound = 0
    community_model.objective = "bio1"
    cobra.io.save_json_model(community_model, 'nboutput/'+sample+'.json')
    solution = community_model.optimize()
util.kbdevutil.save("constraints", constraints)
util.kbdevutil.save("biomass_compounds", biomass_compounds)
util.kbdevutil.save("abundance_by_name", abundance_by_name)
util.kbdevutil.save("species_reactions", species_reactions)
util.kbdevutil.save("biomass_exchange_ids", biomass_exchange_ids)
# Out:
# 1712984841.747641 INFO: The current solver interface glpk doesn't support setting the optimality tolerance.
# 1712984844.243892 INFO: The current solver interface glpk doesn't support setting the optimality tolerance.
# Processing sample: Sample2
# Processing ASV: ASV00002;seqs=7303020;samples=1403 with abundance: 0.0011664528169835532 in sample Sample2
# <Solution 151.387 at 0x7fa1139ebe50>
# Processing ASV: ASV00003;seqs=7068340;samples=1916 with abundance: 0.015863758310976323 in sample Sample2
# <Solution 280.109 at 0x7fa11404d130>
# Processing ASV: ASV00004;seqs=6473178;samples=1764 with abundance: 0.8305144056922897 in sample Sample2
# <Solution 57.494 at 0x7fa0f1683d00>
# Processing ASV: ASV00005;seqs=5940024;samples=3018 with abundance: 0.01123682880360823 in sample Sample2
# <Solution 150.594 at 0x7fa114969430>
# Processing ASV: ASV00006;seqs=5698377;samples=2075 with abundance: 0.14121855437614214 in sample Sample2
# <Solution 149.949 at 0x7fa0d37a4f70>
# EX_biomass(e)_ASV00002 100.0
# EX_biomass(e)_ASV00003 100.0
# EX_biomass(e)_ASV00004 59.69022600715426
# EX_biomass(e)_ASV00005 100.0
# EX_biomass(e)_ASV00006 100.0

# %%
print(solution)
# Out:
# <Solution 71.871 at 0x141a64a60>

# %% [markdown]
# # Loading metabolomics data

# %%
from pandas import read_csv
metabolomics_data = read_csv('metabolomics differences.csv').set_index("day_diet diff").T.to_dict()

# %% [markdown]
# # Loading a single community model

# %%
import cobra
model_list = ["RC-ABX_-1.5","RC-ABX_4.0","RC-ABX_5.5","RC-ABX_6.0","RC-ABX_12.5","RC-ABX_15.5","RC-ABX_21.0"]
model_id = model_list[3]
community_model = cobra.io.read_sbml_model("models/"+model_id+'_comm.xml')
community_model.objective = "bio1"
solution = community_model.optimize()
constraints = {}
solution
# Out:
# 1713299148.6265888 ERROR: '' is not a valid SBML 'SId'.
# <Solution 100.000 at 0x7f7c7cde9550>

# %% [markdown]
# # Add elemental uptake constraint

# %%
from optlang.symbolics import Zero, add
from json import load

element_parameters = {"C":100}
if "constraints" not in globals():
    with open("constraints.json", "r") as jsonIn:   constraints = load(jsonIn)
for sample in asv_abundances:
    #Removing constraints if they're there
    if "elements" in constraints[sample]:
        newmodels[sample].remove_cons_vars(list(constraints[sample]["elements"].values()))
    constraints[sample]["elements"] = {}
    for element, value in element_parameters.items():
        constraints[sample]["elements"][element] = {}
        coef = {}
        for rxn in newmodels[sample].reactions:
            if rxn.id[0:3] == "EX_":
                total = 0
                for metabolite in rxn.metabolites:
                    if element in metabolite.elements:
                        total += metabolite.elements[element] * rxn.metabolites[metabolite]
                if total < 0:    coef[rxn.reverse_variable] = -total
                elif total > 0:  coef[rxn.forward_variable] = total
        constraints[sample]["elements"][element] = newmodels[sample].problem.Constraint(Zero, lb=None, ub=value, name=element+"_element_uptake")
        newmodels[sample].add_cons_vars(constraints[sample]["elements"][element])
        newmodels[sample].solver.update()
        if len(coef) > 0:   constraints[sample]["elements"][element].set_linear_coefficients(coef)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ph/360gp1jx5zg7qyqv076prl240000gn/T/ipykernel_86371/2214453979.py in <module>
#      30 for rxn in community_model.reactions:
#      31     if rxn.id[0:3] == "EX_" and abs(solution.fluxes[rxn.id]) > 0.000001:
# ---> 32         cpd = rxn.metabolites.keys().list()[0]
#      33         print(rxn,solution.fluxes[rxn.id],cpd.formula,cpd.id)
#
# AttributeError: 'dict_keys' object has no attribute 'list'

# %% [markdown]
# # Adding comm-kinetics constraint

# %%
#Removing constraints if they're there
kinetic_coef = 400
if "constraints" not in globals():
    with open("constraints.json", "r") as jsonIn:   constraints = load(jsonIn)
if "species_reactions" not in globals():
    with open("species_reactions.json", "r") as jsonIn:   species_reactions = load(jsonIn)

for sample in asv_abundances:
    if "kinetic" in constraints[sample]:
        newmodels[sample].remove_cons_vars(list(constraints[sample]["elements"].values()))
    constraints[sample]["kinetic"] = {}
    for asv in abundance_by_name[sample]:
        biorxn = newmodels[sample].reactions.get_by_id("bio1")
        coef = {
            biorxn.forward_variable:-kinetic_coef*abundance_by_name[sample][asv],
            biorxn.reverse_variable:kinetic_coef*abundance_by_name[sample][asv]
        }
        for rxn_id in species_reactions[sample][asv]:
            rxn = newmodels[sample].reactions.get_by_id(rxn_id)
            coef[rxn.forward_variable] = coef[rxn.reverse_variable] = 1
        constraints[sample]["kinetic"][asv] = newmodels[sample].problem.Constraint(Zero, lb=None, ub=0, name=asv+"_kinetic")
        if len(coef) > 0:   constraints[sample]["kinetic"][asv].set_linear_coefficients(coef) 
        newmodels[sample].add_cons_vars(constraints[sample]["kinetic"][asv])
        newmodels[sample].solver.update()
# Out:
# Deleting existing constraints
# Deleting existing constraints
# Deleting existing constraints
# Deleting existing constraints
# Deleting existing constraints

# %% [markdown]
# # Constraining model to produce biomass near max value

# %%
fraction_optimal_growth = 0.8
if "constraints" not in globals():
    constraints = util.kbdevutil.load("constraints")
for sample in asv_abundances:
    if "objconst" in constraints:
        community_model.remove_cons_vars(constraints["objconst"])
    obj_value = community_model.slim_optimize()
    coef = community_model.solver.objective.get_linear_coefficients(
        community_model.solver.objective.variables
    )
    constraints["objconst"] = community_model.problem.Constraint(Zero, lb=0.8*obj_value, ub=None, name="objconst")
    community_model.add_cons_vars(constraints["objconst"])
    community_model.solver.update()
    constraints["objconst"].set_linear_coefficients(coef)

# %% [markdown]
# # Minimizing probabilities and maximizing metabolomics agreement

# %%
prob_exp = 1
min_prob = 0.05
ex_weight = 1
media_coef = 100
metabolomics_data = util.kbdevutil.load("metabolomics_data")
found = {}
metabolomics_exchanges = {}
for sample in asv_abundances:
    metabolomics_exchanges = {}
    coef = {}
    row = metabolomics_data["RC-ABX_-1.5"]
    for rxn in community_model.reactions:
        if rxn.id[0:3] == "EX_":
            met_id = rxn.id[3:-3]
            if met_id in row:
                found[met_id] = row[met_id]
                if row[met_id] > 0:
                    print("FORWARD",met_id)
                    metabolomics_exchanges[met_id] = [rxn.id,row[met_id]]
                    coef.update({rxn.forward_variable: -1*media_coef})
                    coef.update({rxn.reverse_variable: 10*media_coef})
                elif row[met_id] < 0:
                    metabolomics_exchanges[met_id] = [rxn.id,row[met_id]]
                    print("REVERSE",met_id)
                    coef.update({rxn.reverse_variable: -1*media_coef})
                    coef.update({rxn.forward_variable: 10*media_coef})
            else:
                print("NO_DATA",met_id)
                coef.update({rxn.forward_variable: ex_weight})
                coef.update({rxn.reverse_variable: ex_weight})
        elif "probability" in rxn.notes:
            coef.update(
                {
                    rxn.forward_variable: max(
                        min_prob, (1 - float(rxn.notes["probability"]) ** prob_exp)
                    )
                }
            )
            coef.update(
                {
                    rxn.reverse_variable: max(
                        min_prob, (1 - float(rxn.notes["probability"]) ** prob_exp)
                    )
                }
            )
    community_model.objective = community_model.problem.Objective(Zero, direction="min")
    community_model.objective.set_linear_coefficients(coef)
    for item in row:
        if item not in found:
            print("NOT_FOUND",item)
# Out:
# NO_DATA 12dgr180
# NO_DATA 15dap
# NO_DATA 2obut
# NO_DATA 34dhphe
# NO_DATA 4abut
# NO_DATA 4ahmmp
# NO_DATA 7a_czp
# NO_DATA C02528
# NO_DATA acald
# REVERSE acgam
# NO_DATA actn_R
# NO_DATA adn
# NO_DATA adocbl
# NO_DATA ala_D
# REVERSE ala_L
# NO_DATA alaasp
# NO_DATA alagln
# NO_DATA alaglu
# NO_DATA alagly
# NO_DATA alahis
# NO_DATA alaleu
# NO_DATA alathr
# NO_DATA anzp
# REVERSE arab_L
# NO_DATA arabttr
# NO_DATA arbt
# NO_DATA arg_L
# NO_DATA arsenb
# NO_DATA biomass(e)_ASV00
# NO_DATA btn
# NO_DATA ca2
# NO_DATA cd2
# NO_DATA cgly
# NO_DATA chlphncl
# NO_DATA chol
# REVERSE cholate
# NO_DATA chols
# NO_DATA cl
# NO_DATA co2
# NO_DATA cobalt2
# NO_DATA crn
# NO_DATA ctbt
# NO_DATA cu2
# NO_DATA czp
# NO_DATA dfdcytd
# NO_DATA dfduri
# NO_DATA dgchol
# NO_DATA dhna
# NO_DATA dopa
# REVERSE drib
# NO_DATA etoh
# NO_DATA fe2
# NO_DATA fe3
# NO_DATA fecrm
# NO_DATA fol
# NO_DATA for
# FORWARD fru
# REVERSE gal
# NO_DATA gam
# NO_DATA gbbtn
# NO_DATA gchola
# REVERSE glc_D
# NO_DATA gln_L
# REVERSE glu_L
# REVERSE gly
# NO_DATA glyasn
# NO_DATA glyasp
# NO_DATA glyb
# NO_DATA glyc
# NO_DATA glycys
# NO_DATA glygln
# NO_DATA glyglu
# NO_DATA glyleu
# NO_DATA glymet
# NO_DATA glyphe
# NO_DATA glypro
# NO_DATA glytyr
# NO_DATA h
# NO_DATA h2o
# NO_DATA hg2
# NO_DATA hxan
# REVERSE ile_L
# NO_DATA k
# NO_DATA kesto
# NO_DATA kestopt
# NO_DATA kestottr
# NO_DATA lac_D
# NO_DATA lac_L
# NO_DATA lactl
# NO_DATA lcts
# REVERSE leu_L
# REVERSE lys_L
# NO_DATA malt
# NO_DATA malthx
# NO_DATA malttr
# NO_DATA man
# NO_DATA met_D
# REVERSE met_L
# NO_DATA metala
# NO_DATA metsox_R_L
# NO_DATA metsox_S_L
# NO_DATA mg2
# NO_DATA mn2
# NO_DATA mnl
# NO_DATA mqn7
# NO_DATA mqn8
# NO_DATA na1
# REVERSE nac
# NO_DATA nchlphncl
# NO_DATA nh4
# NO_DATA no2
# NO_DATA nzp
# NO_DATA o2
# NO_DATA orn
# NO_DATA pb
# NO_DATA pheme
# NO_DATA pi
# NO_DATA pnto_R
# REVERSE pro_L
# NO_DATA ptrc
# NO_DATA q8
# REVERSE rib_D
# NO_DATA ribflv
# NO_DATA salcn
# NO_DATA sbt_D
# REVERSE ser_D
# NO_DATA ser_L
# NO_DATA sheme
# NO_DATA so4
# NO_DATA spmd
# REVERSE succ
# FORWARD sucr
# NO_DATA taur
# NO_DATA tchola
# NO_DATA tdchola
# NO_DATA thm
# FORWARD thr_L
# NO_DATA tre
# NO_DATA trp_L
# NO_DATA tym
# REVERSE tyr_L
# NO_DATA ura
# REVERSE val_L
# NO_DATA xan
# NO_DATA zn2
# NO_DATA 1hibup_S
# NO_DATA 1hibupglu_S
# NO_DATA 1hmdgluc
# NO_DATA 1ohmdz
# NO_DATA 2hatvacid
# NO_DATA 2hatvacidgluc
# NO_DATA 2hatvlac
# NO_DATA 2hatvlacgluc
# NO_DATA 2hibup_S
# NO_DATA 2hibupglu_S
# NO_DATA 2oh_cbz
# NO_DATA 2oh_cbz_glc
# NO_DATA 2oh_mtz
# NO_DATA 2oh_mtz_glc
# NO_DATA 3hibup_S
# NO_DATA 3hibupglu_S
# NO_DATA 3meacmp
# NO_DATA 3oh_cbz
# NO_DATA 3oh_cbz_glc
# NO_DATA 3oh_dlor
# NO_DATA 3oh_dlor_glc
# NO_DATA 3oh_mdea
# NO_DATA 3oh_mdea_glc
# NO_DATA 3oh_mxn
# NO_DATA 3oh_mxn_glc
# NO_DATA 4dh_tpno
# NO_DATA 4dh_tpno_1glc
# NO_DATA 4hmdgluc
# NO_DATA 4oh_dcf
# NO_DATA 4oh_dcf_glc
# NO_DATA 4oh_kp
# NO_DATA 4oh_kp_glc
# NO_DATA 4oh_levole
# NO_DATA 4oh_levole_glc
# NO_DATA 4oh_meth
# NO_DATA 4oh_meth_glc
# NO_DATA 4oh_propl
# NO_DATA 4oh_propl_glc
# NO_DATA 4oh_trz
# NO_DATA 4oh_trz_glc
# NO_DATA 4oh_vcz
# NO_DATA 4oh_vcz_glc
# NO_DATA 4ohmdz
# NO_DATA 5oh_sulfp
# NO_DATA 5oh_sulfp_glc
# NO_DATA 5ohfvs
# NO_DATA 5ohfvsglu
# NO_DATA 6bhglz
# NO_DATA 6bhglzglc
# NO_DATA 6ohfvs
# NO_DATA 6ohfvsglu
# NO_DATA 7bhglz
# NO_DATA 7bhglzglc
# NO_DATA 7oh_efv
# NO_DATA 7oh_efv_glc
# NO_DATA 814dioh_efv
# NO_DATA 814dioh_efv_glc
# NO_DATA 8oh_efv
# NO_DATA 8oh_efv_glc
# NO_DATA N_oh_phtn
# NO_DATA N_oh_phtn_glc
# NO_DATA R_6oh_warf
# NO_DATA R_6oh_warf_glc
# NO_DATA R_7oh_warf
# NO_DATA R_7oh_warf_glc
# NO_DATA R_8oh_warf
# NO_DATA R_8oh_warf_glc
# NO_DATA S_4oh_warf
# NO_DATA S_4oh_warf_glc
# NO_DATA S_6oh_warf
# NO_DATA S_6oh_warf_glc
# NO_DATA ac_amn_b_gly
# NO_DATA ac_amn_b_gly_glc
# NO_DATA acmp
# NO_DATA acmp_glc
# NO_DATA acmpglu
# NO_DATA alpz_4oh
# NO_DATA alpz_4oh_glc
# NO_DATA alpz_aoh
# NO_DATA alpz_aoh_glc
# NO_DATA am14
# NO_DATA am14_glc
# NO_DATA am1ccs
# NO_DATA am1cglc
# NO_DATA am5
# NO_DATA am5_glc
# NO_DATA am6
# NO_DATA am6_glc
# NO_DATA amio
# NO_DATA amio_c
# NO_DATA amio_c_glc
# NO_DATA amio_glc
# NO_DATA amn_b_gly
# NO_DATA amn_b_gly_glc
# NO_DATA amntd_m6
# NO_DATA amntd_m6_glc
# NO_DATA atvacid
# NO_DATA atvacylgluc
# NO_DATA atvethgluc
# NO_DATA atvlac
# NO_DATA atvlacgluc
# NO_DATA bhpm
# NO_DATA bhpm_glc
# NO_DATA bilr_355
# NO_DATA bilr_M10
# NO_DATA bilr_M12
# NO_DATA bilr_M14
# NO_DATA bilr_M15
# NO_DATA bilr_M16
# NO_DATA bilr_M7
# NO_DATA bsn
# NO_DATA bsn_glc
# NO_DATA bz
# NO_DATA bz_glc
# NO_DATA caribup_s
# NO_DATA caribupglu_S
# NO_DATA cbz
# NO_DATA cbz_glc
# NO_DATA cd6168
# NO_DATA cd6168_glc
# NO_DATA chlphncl_glc
# NO_DATA clcxb
# NO_DATA clcxb_c
# NO_DATA clcxb_c_glc
# NO_DATA clcxb_glc
# NO_DATA clobi_c
# NO_DATA clobi_glc
# NO_DATA crvsm1
# NO_DATA crvsm23
# NO_DATA cvm1gluc
# NO_DATA cvm23gluc
# NO_DATA daa
# NO_DATA daa_glc
# NO_DATA dcf
# NO_DATA dcf_glc
# NO_DATA ddea
# NO_DATA ddea_glc
# NO_DATA des_astzl
# NO_DATA des_astzl_glc
# NO_DATA digoxin
# NO_DATA digoxin_glc
# NO_DATA dlb
# NO_DATA dlb_glc
# NO_DATA dnpz_5des
# NO_DATA dnpz_6des
# NO_DATA dnpz_m11
# NO_DATA dnpz_m12
# NO_DATA dnpz_m13
# NO_DATA dnpz_m14
# NO_DATA dnpz_m9
# NO_DATA doh_etr
# NO_DATA doh_etr_glc
# NO_DATA doh_vcz
# NO_DATA doh_vcz_glc
# NO_DATA dxo
# NO_DATA dxo_glc
# NO_DATA efv
# NO_DATA efv_glc
# NO_DATA eltr
# NO_DATA eltr_glc
# NO_DATA eltr_m3
# NO_DATA eltr_m4
# NO_DATA estradiol
# NO_DATA estriol
# NO_DATA estrone
# NO_DATA eztmb
# NO_DATA eztmb_glc
# NO_DATA fvs
# NO_DATA fvsgluc
# NO_DATA fvstet
# NO_DATA fvstetglu
# NO_DATA glc3meacp
# NO_DATA glcur
# NO_DATA gltmn
# NO_DATA gltmn_glc
# NO_DATA glyc3p
# NO_DATA gmfl
# NO_DATA gmfl_glc
# NO_DATA gmfl_mI
# NO_DATA gmfl_mII
# NO_DATA gmfl_mIII
# NO_DATA gmfl_mIII_glc
# NO_DATA gmfl_mII_glc
# NO_DATA gmfl_mI_glc
# NO_DATA gtacmp
# NO_DATA hst
# NO_DATA hst_37_diglc
# NO_DATA hst_3_glc
# NO_DATA hst_3_s
# NO_DATA hst_3glc_7s
# NO_DATA hst_7_glc
# NO_DATA hst_7_s
# NO_DATA hst_7glc_3s
# NO_DATA ibup_S
# NO_DATA ibupgluc
# NO_DATA imn
# NO_DATA imn_glc
# NO_DATA inv
# NO_DATA inv_m1
# NO_DATA isosorbide_5mn
# NO_DATA isosorbide_5mn_glc
# NO_DATA kprofen
# NO_DATA kprofen_glc
# NO_DATA lst4exp
# NO_DATA lstn
# NO_DATA lstn1gluc
# NO_DATA lstnm4
# NO_DATA lstnm7
# NO_DATA mantr
# NO_DATA mdz
# NO_DATA mdz_glc
# NO_DATA mdzglc
# REVERSE melib
# NO_DATA miso
# NO_DATA miso_glc
# NO_DATA mrphn
# NO_DATA mrphn_3glc
# NO_DATA mrphn_6glc
# NO_DATA mtz
# NO_DATA mtz_glc
# NO_DATA nsldp_m5
# NO_DATA nsldp_m5_glc
# NO_DATA nverp
# NO_DATA nverp_glc
# NO_DATA odsm_egltmn
# NO_DATA odsm_egltmn_glc
# NO_DATA odsm_gltmn
# NO_DATA odsm_gltmn_glc
# NO_DATA oh_etr
# NO_DATA oh_etr_glc
# NO_DATA oh_pbl
# NO_DATA oh_pbl_glc
# NO_DATA phppa
# NO_DATA phppa_glc
# NO_DATA phtn_glc
# NO_DATA prob
# NO_DATA prob_glc
# NO_DATA pront
# NO_DATA pront_glc
# NO_DATA propl
# NO_DATA propl_glc
# NO_DATA prx_mI
# NO_DATA prx_mII
# NO_DATA prx_mII_glc
# NO_DATA prx_mI_glc
# NO_DATA ptvst
# NO_DATA ptvstgluc
# NO_DATA pvs
# NO_DATA pvsgluc
# NO_DATA r406
# NO_DATA r406_glc
# NO_DATA r529
# NO_DATA r529_glc
# NO_DATA regfnb
# NO_DATA rep
# NO_DATA rep_glc
# NO_DATA rpn_104557
# NO_DATA rpn_104557_cb_glc
# NO_DATA rpn_96990
# NO_DATA rpn_96990_glc
# NO_DATA rpn_oh
# NO_DATA rpn_oh_glc
# NO_DATA rsv
# NO_DATA rsvgluc
# NO_DATA sb_611855
# NO_DATA sb_y
# NO_DATA sch_488128
# NO_DATA sch_57871
# NO_DATA sch_57871_glc
# NO_DATA sfnd_1689
# NO_DATA sfnd_1689_glc
# NO_DATA sftz
# NO_DATA sftz_glc
# NO_DATA simvgluc
# NO_DATA smap
# NO_DATA smap_glc
# NO_DATA smvacid
# NO_DATA sn38
# NO_DATA sn38g
# NO_DATA spz
# NO_DATA spz_glc
# NO_DATA spz_sfn
# NO_DATA spz_sfn_glc
# NO_DATA stg
# NO_DATA stg_m3
# NO_DATA stg_m4
# NO_DATA stys
# NO_DATA tat
# NO_DATA tgz
# NO_DATA tgz_glc
# NO_DATA thsacmp
# NO_DATA tlf_a
# NO_DATA tlf_a_1a
# NO_DATA tlf_a_1b
# NO_DATA tlf_a_1x
# NO_DATA tlf_a_2
# NO_DATA tlf_a_2a
# NO_DATA tlf_a_3
# NO_DATA tlf_a_4
# NO_DATA tlf_a_m1
# NO_DATA tlf_a_m2
# NO_DATA tlf_a_m3
# NO_DATA tlf_a_m4
# NO_DATA tlf_a_m4a
# NO_DATA tlf_a_m5
# NO_DATA tlf_a_m5a
# NO_DATA tlf_a_m5b
# NO_DATA tlf_a_m6
# NO_DATA tlf_a_m9
# NO_DATA tlms
# NO_DATA tlms_glc
# NO_DATA tmacmp
# NO_DATA tolcp
# NO_DATA tolcp_ac
# NO_DATA tolcp_ac_glc
# NO_DATA tolcp_am
# NO_DATA tolcp_am_glc
# NO_DATA tolcp_glc
# NO_DATA tpno_1glc_4g
# NO_DATA tpno_4g
# NO_DATA tpno_4glc
# NO_DATA tpnoh
# NO_DATA tsacmgluc
# NO_DATA xyl_D
# REVERSE fum
# NO_DATA 4hbz
# REVERSE phe_L
# REVERSE dchac
# NO_DATA dextrin
# NO_DATA tdechola
# NO_DATA 26dap_M
# FORWARD asn_L
# NO_DATA cbl1
# NO_DATA cbl2
# NO_DATA cytd
# NO_DATA dad_2
# NO_DATA dcyt
# NO_DATA dgsn
# NO_DATA din
# NO_DATA duri
# NO_DATA etha
# NO_DATA ins
# REVERSE raffin
# NO_DATA thymd
# NO_DATA uri
# NO_DATA pydxn
# REVERSE cit
# NO_DATA estradiolglc
# NO_DATA estriolglc
# NO_DATA estroneglc
# NO_DATA regfnb_glc
# NO_DATA urea
# NO_DATA bhb
# REVERSE mal_L
# NO_DATA pydx
# NO_DATA 2dmmq8
# NO_DATA galctn_D
# NO_DATA ocdca
# NO_DATA 4abz
# NO_DATA 5fura
# NO_DATA 5mthf
# NO_DATA ade
# NO_DATA alltn
# REVERSE asp_L
# NO_DATA csn
# FORWARD cys_L
# NO_DATA fcsn
# NO_DATA glcn
# NO_DATA gua
# NO_DATA h2s
# NO_DATA nmn
# NO_DATA no3
# NO_DATA ppi
# NO_DATA pydam
# REVERSE pyr
# NO_DATA r788
# NO_DATA thf
# NO_DATA tma
# NO_DATA tmao
# NO_DATA 3mop
# NO_DATA 2ddglcn
# NO_DATA 2hyoxplac
# NO_DATA 34dhpha
# NO_DATA 3hphac
# NO_DATA 7dhcdchol
# NO_DATA 7ocholate
# NO_DATA Lcyst
# NO_DATA acac
# NO_DATA aso3
# NO_DATA aso4
# NO_DATA biomass(e)_ASV00
# NO_DATA butso3
# NO_DATA bzam
# NO_DATA cynt
# NO_DATA dh5fura
# NO_DATA dhcinnm
# NO_DATA dhpppn
# NO_DATA dma
# NO_DATA dms
# NO_DATA dmso
# NO_DATA ethso3
# NO_DATA fald
# NO_DATA fruur
# NO_DATA fuc1p_L
# NO_DATA g6p
# NO_DATA galct_D
# NO_DATA galur
# NO_DATA glcr
# NO_DATA glyclt
# NO_DATA gsn
# NO_DATA h2
# REVERSE hdca
# NO_DATA hexs
# NO_DATA idon_L
# NO_DATA ind3ac
# NO_DATA isetac
# NO_DATA man6p
# NO_DATA meoh
# NO_DATA mops
# NO_DATA mso3
# NO_DATA ncam
# NO_DATA oxa
# NO_DATA pac
# NO_DATA pcresol
# NO_DATA pime
# NO_DATA pppn
# REVERSE rmn
# NO_DATA sel
# NO_DATA selni
# NO_DATA sulfac
# NO_DATA tagur
# NO_DATA tsul
# REVERSE ttdca
# NO_DATA 5asa
# NO_DATA ac5asa
# NO_DATA acisnzd
# NO_DATA isnzd
# NO_DATA xtsn
# NO_DATA 4hoxpacd
# NO_DATA 5htrp
# NO_DATA 5mta
# NO_DATA acnam
# NO_DATA gcald
# NO_DATA srtn
# NO_DATA trypta
# REVERSE ddca
# NO_DATA cinnm
# NO_DATA 12ppd_S
# REVERSE fuc_L
# NO_DATA HC00319
# FORWARD inost
# NO_DATA arab_D
# NO_DATA diact
# NO_DATA so3
# NO_DATA abz_ala_b
# NO_DATA bzd
# NO_DATA neopront
# NO_DATA olsa
# NO_DATA sanilamide
# NO_DATA ssz
# NO_DATA sulfp
# NO_DATA tab
# NO_DATA biomass(e)_ASV00
# NO_DATA 2omfuc
# NO_DATA 2omxyl
# NO_DATA 3ddlhept
# NO_DATA Ser_Thr
# NO_DATA T_antigen
# NO_DATA Tn_antigen
# NO_DATA Tyr_ggn
# NO_DATA acerA
# NO_DATA acgal
# NO_DATA acgalglcur
# NO_DATA acgalidour
# NO_DATA acgalidour2s
# NO_DATA amylopect900
# NO_DATA amylose300
# NO_DATA apio-D
# NO_DATA arabinan101
# NO_DATA arabinogal
# NO_DATA arabinoxyl
# NO_DATA biomass(e)_ASV00
# NO_DATA brv
# NO_DATA bvu
# NO_DATA core2
# NO_DATA core3
# NO_DATA core4
# NO_DATA core5
# NO_DATA core6
# NO_DATA core7
# NO_DATA core8
# NO_DATA cro4
# NO_DATA cspg_a
# NO_DATA cspg_a_degr
# NO_DATA cspg_ab_rest
# NO_DATA cspg_b
# NO_DATA cspg_b_degr
# NO_DATA cspg_c
# NO_DATA cspg_c_degr
# NO_DATA cspg_c_rest
# NO_DATA dextran40
# NO_DATA dsT_antigen
# NO_DATA f1a
# NO_DATA galactan
# NO_DATA gam26s
# NO_DATA glygn2
# NO_DATA glygn4
# NO_DATA glygn5
# NO_DATA gncore1
# NO_DATA gncore2
# NO_DATA gthox
# NO_DATA ha
# NO_DATA ha_deg1
# NO_DATA ha_pre1
# NO_DATA homogal
# NO_DATA hspg
# NO_DATA hspg_degr_1
# NO_DATA hspg_degr_10
# NO_DATA hspg_degr_11
# NO_DATA hspg_degr_12
# NO_DATA hspg_degr_13
# NO_DATA hspg_degr_14
# NO_DATA hspg_degr_15
# NO_DATA hspg_degr_2
# NO_DATA hspg_degr_3
# NO_DATA hspg_degr_4
# NO_DATA hspg_degr_5
# NO_DATA hspg_degr_6
# NO_DATA hspg_degr_7
# NO_DATA hspg_degr_8
# NO_DATA hspg_degr_9
# NO_DATA hspg_rest
# NO_DATA idour
# NO_DATA inulin
# NO_DATA isobut
# NO_DATA isocapr
# NO_DATA isoval
# NO_DATA kdo
# NO_DATA levan1000
# NO_DATA levanb
# NO_DATA levanttr
# NO_DATA levantttr
# NO_DATA mannan
# NO_DATA pect
# NO_DATA pecticgal
# NO_DATA psics_D
# NO_DATA pullulan1200
# NO_DATA rhamnogalurI
# NO_DATA rhamnogalurII
# NO_DATA sT_antigen
# NO_DATA sTn_antigen
# NO_DATA srv
# NO_DATA strch1
# NO_DATA strch2
# NO_DATA xylottr
# NO_DATA gthrd
# NO_DATA phenol
# NO_DATA biomass(e)_ASV00
# NO_DATA chor
# NO_DATA community_biom
# NOT_FOUND 12_Ketolithocholic acid
# NOT_FOUND 5oxpro
# NOT_FOUND all_D
# NOT_FOUND dca
# NOT_FOUND hxa
# NOT_FOUND lnlcACP
# NOT_FOUND HC02191
# NOT_FOUND octa
# NOT_FOUND orn_L
# NOT_FOUND C10164
# NOT_FOUND HC02194
# NOT_FOUND pta
# NOT_FOUND cis_Oleic acid
# NOT_FOUND meso_Erythritol
# NOT_FOUND 4hpro_LT

# %% [markdown]
# # Test code

# %%
sample = "Sample2"
with open("nboutput/test.lp", "w") as out:
    out.write(str(community_model.solver))
solution = community_model.optimize()
print(solution)
# Out:
# <Solution 2849.156 at 0x7fa114f024f0>
