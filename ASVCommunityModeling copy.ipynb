# %% [markdown]
# # Configure KBase Jupyter Dev Environment

# %%
# %run sludgecommutil.py
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
# %tb
# Out:
# Output files printed to:/home/freiburger/Documents/sludge/Sludge/nboutput when using KBDevUtils.output_dir

# %% [markdown]
# # Processing ASV mappings

# %%
# creating a mapping of ASVs to genomes
# original_mappings = util.load("Test_AGORA2_Bioreactor_over95_best_mappings_02-14-25")
# asv_mappings = {}
# genomes_mapped = {}
# for asv in original_mappings.keys():
#     for genome_id in original_mappings[asv][1]:
#         if asv not in asv_mappings:
#             asv_mappings[asv] = []
#         if genome_id not in asv_mappings[asv]:
#             asv_mappings[asv].append(genome_id)
#             if genome_id not in genomes_mapped:
#                 genomes_mapped[genome_id] = []
#             genomes_mapped[genome_id].append(asv)
# util.save("asv_mappings", asv_mappings)
# util.save("genomes_mapped", genomes_mapped)

from json import load, dump
# matches_to_get = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/NewWesternDiet/datacache/matches_to_get.json", 'r'))
matches_to_get = load(open("/home/freiburger/Documents/MicrobiomeNotebooks/NewWesternDiet/datacache/matches_to_get.json","r"))
ASV_genomes = {ID: list([x for y in matches.values() for x in y]) for ID, matches in matches_to_get.items()}
# display(ASV_genomes)

# creating the ASVset
asv_list = list(ASV_genomes.keys())
asvset_asvs = {}
asv_asvset = {}
asvset_genomes = {}
genome_asvsets = {}

for asv, genomes in ASV_genomes.items():
    for genome in genomes:
        genome_asvsets.setdefault(genome, []).append(asv)

zeros = []
worked = []
similarity_threhsold = 0.5
added = set()
for i, (asv, genomes) in enumerate(ASV_genomes.items()):
    if asv in asv_asvset or asv in added:  continue
    if len(genomes) == 0:
        zeros.append(asv)
        continue
    asvset_asvs[asv] = [asv]
    asvset_genomes[asv] = genomes.copy()
    for j, (asv_j, genomes_j) in enumerate(ASV_genomes.items()):
        if i == j or len(genomes_j) == 0 or asv_j in asvset_asvs:  continue
        denominator = min(len(genomes), len(genomes_j))
        common = set(genomes) & set(genomes_j)
        score = len(common) / denominator
        if score < similarity_threhsold:  continue
        asvset_asvs[asv].append(asv_j)
        asvset_genomes[asv].extend(genomes_j)
        worked.append((asv, asv_j))
    added.update(asvset_asvs[asv])
    asvset_genomes[asv] = list(set(asvset_genomes[asv]))

util.save("asvset_asvs", asvset_asvs)
util.save("asv_asvset", asv_asvset)
util.save("asvset_genomes", asvset_genomes)
util.save("genome_asvsets", genome_asvsets)

print("Denominator 0 for ", len(zeros), zeros)
print("Worked for ", len(worked), worked, end="\n\n")
print("Genomes:", len(set([x for gs in asvset_genomes.values() for x in gs])))
print("ASVs:", len(ASV_genomes))
print("ASV sets:", len(asvset_asvs))

asvset_asvs = load(open("/home/freiburger/Documents/MicrobiomeNotebooks/NewWesternDiet/datacache/ASV_sets.json","r"))
display(asvset_asvs)
# Out:
# Denominator 0 for  3 ['03a6a6d84a7be4b11b6467c91ca79d57', '76ef356d895e6434580f18ab74a63e6c', 'eca00dcc9a01255b6cb66fbd5b3bd285']
# ...

# %% [markdown]
# # Checking if all mapped genomes are in AGORA workspace

# %% [markdown]
# ## checking that all of the Narrative objects are in the ASV set genomes

# %%
ws_client = util.ws_client()
genomes_nar = 221042
output = ws_client.list_objects({
    "ids":[genomes_nar],
    "includeMetadata":1,
    "type":"KBaseGenomes.Genome"
})

# output = ws_client.list_objects({"ids":[genomes_nar]})
genome_hash = {item[1]:item for item in output}
util.save("genome_hash", genome_hash)

# asvssets_with_missing_genomes = {}
# missing_genomes = {}
# # asvset_genomes = util.load("asvset_genomes")
# for asv, genomes in asv_sets.items():
#     for genomeid in genomes:
#         if any([genomeid in genome_hash, genomeid+".RAST" in genome_hash]):  continue
#         missing_genomes.setdefault(genomeid, []).append(asv)
#         asvssets_with_missing_genomes.setdefault(asvset, []).append(genomeid)
# util.save("missing_genomes", missing_genomes)
# util.save("asvssets_with_missing_genomes", asvssets_with_missing_genomes)
# for genomeid in missing_genomes:
#     print(genomeid,len(missing_genomes[genomeid]))
# for asvset in asvssets_with_missing_genomes:
#     print(asvset,len(asvssets_with_missing_genomes[asvset]),len(asvset_genomes[asvset]))
#     if len(asvset_genomes[asvset]) <= 2:
#         for genomeid in asvset_genomes[asvset]:
#             if genomeid in missing_genomes:
#                 print(genomeid)

display(output)
# Out:
# [[2164,
#   '1352.8344__sludge_genomes.RAST',
#   'KBaseGenomes.Genome-11.1',
#   '2025-10-24T07:21:57+0000',
#   2,
#   'freiburgermsu',
#   221042,
#   'freiburgermsu:narrative_1750891820199',
#   'be593c7febc4996b3f5fdfd75b463392',
#   8249310,
#   {'Taxonomy': 'd__Bacteria;p__Bacillota;c__Bacilli;o__Lactobacillales;f__Enterococcaceae;g__Enterococcus_B;s__Enterococcus_B lactis',
#    'Size': '2754780',
#    'GTDB_lineage': 'd__Bacteria;p__Bacillota;c__Bacilli;o__Lactobacillales;f__Enterococcaceae;g__Enterococcus_B;s__Enterococcus_B lactis',
#    'GTDB_taxon_id': 's__Enterococcus_B lactis',
#    'GTDB_source_ver': '214.1',
#    'Source': 'KBase',
#    'Name': 'unknown taxon',
#    'GC content': '0.382',
#    'Genetic code': '11',
#    'Number of Genome Level Warnings': '1',
#    'Source ID': '1352.8344__sludge_genomes.RAST',
#    'Number of Protein Encoding Genes': '2849',
#    'Assembly Object': '221042/2122/2',
#    'Number contigs': '75',
#    'Domain': 'B',
# ...

# %% [markdown]
# # Developing names for ASV sets

# %% [markdown]
# ## GTDB Taxonomy

# %%
taxa = set([x[10]["Taxonomy"] for x in genome_hash.values()])
display(taxa)
genome_hash["1352.8344__sludge_genomes.RAST"]
# Out:
# {'d__Bacteria;p__Pseudomonadota;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E fluorescens_BR',
#  'Unclassified Archaea',
#  'd__Bacteria;p__Pseudomonadota;c__Gammaproteobacteria;o__Burkholderiales;f__Burkholderiaceae_B;g__Polaromonas;s__Polaromonas sp002278925',
#  'd__Bacteria;p__Bacillota_A;c__Clostridia;o__Clostridiales;f__Clostridiaceae;g__Clostridium_H;s__Clostridium_H homopropionicum',
#  'd__Bacteria;p__Pseudomonadota;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_B;s__Pseudomonas_B luteola',
#  'd__Bacteria;p__Pseudomonadota;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas_E;s__Pseudomonas_E costantinii',
#  'd__Bacteria;p__Bacillota_A;c__Clostridia;o__Tissierellales;f__Tepidimicrobiaceae;g__Mt11;s__Mt11 sp001282665',
#  'd__Bacteria;p__Bacillota_A;c__Clostridia;o__Oscillospirales;f__Oscillospiraceae;g__Oscillibacter;s__Oscillibacter ruminantium',
# ...

# %%
taxonomical_codes = {'d': 'Domain', 'k': 'Kingdom', 'p': 'Phylum', 'c': 'Class', 'o': 'Order', 'f': 'Family', 'g': 'Genus', 's': 'Species'}

gtdb_taxonomy = {}
for asv, info in genome_hash.items():
    gtdb_taxonomy.setdefault(asv, {})
    for p in info[10]["Taxonomy"].split(';'): 
        if "unclassified" in p.lower():
            value = p.lower().replace("unclassified", "").strip().capitalize()
            if value == "": continue
            print(p)
            level = "Domain"
        else:
            level, value = p.split('__')
            # print(content)
            level = taxonomical_codes[level] 
        # print('\n')
        # print(dict(content))
        gtdb_taxonomy[asv][level] = value

print(gtdb_taxonomy["1352.8344__sludge_genomes.RAST"])
display(list(gtdb_taxonomy.items())[:4])

from json import dump
dump(gtdb_taxonomy, open("gtdb_taxonomy.json", "w"), indent=3)
# Out:
# Unclassified Archaea
# Unclassified Bacteria
# Unclassified Archaea
# Unclassified Bacteria
# Unclassified Bacteria
# Unclassified Bacteria
# {'Domain': 'Bacteria', 'Phylum': 'Bacillota', 'Class': 'Bacilli', 'Order': 'Lactobacillales', 'Family': 'Enterococcaceae', 'Genus': 'Enterococcus_B', 'Species': 'Enterococcus_B lactis'}
# [('1352.8344__sludge_genomes.RAST',
#   {'Domain': 'Bacteria',
#    'Phylum': 'Bacillota',
#    'Class': 'Bacilli',
#    'Order': 'Lactobacillales',
#    'Family': 'Enterococcaceae',
#    'Genus': 'Enterococcus_B',
#    'Species': 'Enterococcus_B lactis'}),
#  ('1443434.7__sludge_genomes.RAST',
#   {'Domain': 'Bacteria',
#    'Phylum': 'Pseudomonadota',
#    'Class': 'Alphaproteobacteria',
#    'Order': 'Caulobacterales',
#    'Family': 'Caulobacteraceae',
#    'Genus': 'Brevundimonas',
#    'Species': 'Brevundimonas abyssalis'}),
#  ('28141.185__sludge_genomes.RAST',
#   {'Domain': 'Bacteria',
#    'Phylum': 'Pseudomonadota',
# ...

# %% [markdown]
# ### Comparing GTDB and MiDAS taxonomies

# %%
from json import load, dump
from collections import Counter

matches_to_get = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/NewWesternDiet/datacache/matches_to_get.json", 'r'))
md5_geneIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/NewWesternDiet/datacache/md5_geneID.json", 'r'))
gtdb_taxonomy = load(open("/Users/andrewfreiburger/Documents/Research/sludge/gtdb_taxonomy.json", 'r'))
# midas_taxonomy = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/new_taxonomy.json", 'r'))

match_genomes_counts = {}
match_genomes = {}
level = "Family"
for ASV, contents in matches_to_get.items():
    # midas = midas_taxonomy[ASV][level]
    # midas = ASV
    print(ASV)
    match_genomes_counts.setdefault(ASV, [])
    match_genomes.setdefault(ASV, [])
    for score, md5s in contents.items():
        for md5 in md5s:
            genomeID = md5_geneIDs[md5].split("|")[1].split(".rna")[0]
            if genomeID + "__sludge_genomes.RAST" not in gtdb_taxonomy:
                print(genomeID, "is missing")
                continue
            taxonomy = gtdb_taxonomy[genomeID + "__sludge_genomes.RAST"]
            if level not in taxonomy:
                print(genomeID, "is missing", level)
                continue
            print(taxonomy[level])
            match_genomes_counts[ASV].append(taxonomy[level])
            match_genomes[ASV].append(genomeID)
    match_genomes_counts[ASV] = dict(Counter(match_genomes_counts[ASV]).most_common())


#  = {ASV: [gtdb_taxonomy[md5_geneIDs[md5].split("|")[1].split(".rna")[0]] + "__sludge_genomes.RAST"
#                         for md5 in md5s]
                     
                    # for score, md5s in contents.items()}
util.save("match_genomes", match_genomes)


from pandas import DataFrame, Series
from json import dump

midas_taxonomy = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/new_taxonomy.json", 'r'))
match_genomes_df = DataFrame({k: Series(v) for k, v in match_genomes_counts.items()}).T
match_genomes_df.index = [midas_taxonomy[i][level] for i in match_genomes_df.index]
match_genomes_df.index.name = f"Midas {level}"
match_genomes_df = match_genomes_df.groupby(level=0).sum()
# match_genomes_df = DataFrame(match_genomes)
display(match_genomes_df)

match_genomes_js = {}
for midas, content in match_genomes_df.T.to_dict().items():
    series = Series(content)
    series = series[series > 0]
    match_genomes_js[midas] = {k: int(v) for k, v in sorted(series.to_dict().items(), key=lambda item: item[1], reverse=True)}

display(match_genomes_js)
util.save("match_genomes_counts", match_genomes_js)


list(match_genomes.items())[:5]
# list(matches_to_get.items())
# Out:
# 021d1583edfe105a9c99264ea9f3d2d6
# Dysgonomonadaceae
# Dysgonomonadaceae
# Dysgonomonadaceae
# Enterobacteriaceae
# Dysgonomonadaceae
# Dysgonomonadaceae
# 6075255b58efbd350ad34112f80f970a
# Moorellaceae
# Moorellaceae
# Dethiobacteraceae
# Moorellaceae
# Moorellaceae
# Moorellaceae
# cf506e6252da1013261a93132ed38efe
# Syntrophobotulaceae
# Dethiosulfatibacteraceae
# Alkalibacteraceae
# Tindalliaceae
# Thermohalobacteraceae
# Gottschalkiaceae
# Alkalibacteraceae
# Thermohalobacteraceae
# Gottschalkiaceae
# 8466f2635d9fbf9c51a04877474f3d09
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# Burkholderiaceae_C
# 4adbf4beb8d2b17f63b543e4d9aa39b6
# Paludibacteraceae
# Paludibacteraceae
# Paludibacteraceae
# Paludibacteraceae
# Enterobacteriaceae
# Enterobacteriaceae
# ...

# %% [markdown]
# ### counting GTDB generas for each ASVset

# %%
# ws_client = util.ws_client()
# output = ws_client.list_objects({
#     "ids":[178418],
#     "includeMetadata":1,
#     "type":"KBaseGenomes.Genome"
# })
asvname_taxonomy = {}
name_taxonomy = {}

from json import load
asv_sets = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/NewWesternDiet/datacache/ASV_sets.json","r"))
# asv_sets

# genome_hash = {}
# for item in output:
#     genome_hash[item[1]] = item
# util.save("genome_hash",genome_hash)

#All of the genome taxonomies are "Unconfirmed Organism"
asvset_genres = {}
for asvset, genomes in asv_sets.items():
    asvset_genres.setdefault(asvset, {})
    for genome in genomes:        
        if genome+"__sludge_genomes.RAST" in genome_hash:
            genome = genome+"__sludge_genomes.RAST"
        name = genome_hash[genome][10]["Name"]
        name_taxonomy[name] = genome_hash[genome][10]["Taxonomy"]
        asvset_genres[asvset][name] += 1
util.save("asvset_genres",asvset_genres)
# util.save("genre_genomes",genre_genomes)


# asvset_names = {}
# genre_counts = {}
# for asvset in asvset_genres:
#     best = None
#     best_score = 0
#     for genre in asvset_genres[asvset]:
#         if asvset_genres[asvset][genre] > best_score:
#             best = genre
#             best_score = asvset_genres[asvset][genre]
#     if not best:
#         best = "none"
#     if best not in genre_counts:
#         genre_counts[best] = 0
#     genre_counts[best] += 1
#     asvset_names[asvset] = best+"."+str(genre_counts[best])
#     asvname_taxonomy[asvset_names[asvset]] = name_taxonomy[best]
# util.save("genre_counts",genre_counts)
# util.save("asvset_names",asvset_names)
# util.save("asvname_taxonomy",asvname_taxonomy)

# %% [markdown]
# # Pulling genomes and getting functions hash from all genomes

# %%
#Now building asv genome objects and saving to file (will be loaded to KBase)
# from cobrakbase.core.kbasegenome.genome import KBaseGenome
from numpy import mean
from json import load
from os import path
from tqdm import tqdm

midas_taxonomy = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/new_taxonomy.json", 'r'))
#TODO:  combine the mapped genomes of ASVs into a single ASV in a different code cell and then 
asv_sets = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/NewWesternDiet/datacache/ASV_sets.json", 'r'))   # asvset_asvs = util.load("asvset_asvs")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
#asvset_genomes = util.load("asvset_genomes")
# asvset_names = util.load("asvset_names")
# genre_genomes = util.load("genre_genomes")
genome_hash = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/genome_hash.json", 'r'))    # genome_hash = util.load("genome_hash")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))

functions = util.load("functions")  #??
feature_aliases = util.load("feature_aliases")
feature_probabilities = util.load("feature_probabilities")
template_genome = util.load("TemplateGenome")
features = {}
ws_client = util.ws_client()
genomes_nar = 221042
#The 1352.8344 organism errored-out in the RAST annotation pipeline

for ASV_md5, genomesIDs in tqdm(match_genomes.items()):
    # asv_genus = midas_taxonomy[ASV]["Genus"]
    if ASV_md5 not in iterativeIDs:
        print(f"The {ASV_md5} is missing in iterativeIDs")
        continue
    asv_genus = iterativeIDs[ASV_md5]
    if (path.exists(f"/Users/andrewfreiburger/Documents/Research/sludge/datacache/Assemblies/{asv_genus}.fasta")
        and path.exists(f"/Users/andrewfreiburger/Documents/Research/sludge/data/genomes/{asv_genus}.json")):
        print(f"{asv_genus} has already been processed and will be skipped")
        continue
    genre = asv_genus.split(".")[0]
    print("Processing ", asv_genus)
    #Loading template genome
    template_genome = util.load("TemplateGenome")
    #Setting metadata
    genomes = [g+"__sludge_genomes.RAST" for g in genomesIDs]
    template_genome.update({
        "assembly_ref": f"{genomes_nar}/{asv_genus}.assembly",
        "dna_size": 0,
        "scientific_name": midas_taxonomy[ASV_md5],
        "taxonomy": midas_taxonomy[ASV_md5],
        "gc_content": mean([float(genome_hash[g][10]["GC content"]) for g in genomes]),
        "id": asv_genus,
        "contig_ids": [],
        "contig_lengths": [],
        "num_contigs": 0,
        "source": "Sludge",
        "warnings": ["Artificial genome created to support ASV modeling"],
        "features": [],
        "cdss": [],
        "source_id": "|".join(genomes),
        "molecule_type": "ASV derived genome",
        "genome_type": "ASV derived genome",
        "domain": midas_taxonomy[ASV_md5]["Kingdom"],
        "ontologies_present": {},
        "ontology_events": []
    })

    md5_list = []
    functions.setdefault(asv_genus,{})
    for genomeID in tqdm(genomes):
        if genomeID not in genome_hash:  continue
        info = genome_hash[genomeID]
        genome = util.msrecon.kbase_api.get_object(genomeID, genomes_nar)

        genome_functions = {}
        for ftr in genome["features"]:
            if "functions" not in ftr:  continue
            for function in ftr["functions"]:
                if function not in functions[asv_genus]:
                    ftrid = f"{asv_genus}_{len(template_genome['contig_ids'])+1}"
                    ##updating the template_genome
                    template_genome["contig_ids"].append(ftrid+".contig")
                    template_genome["contig_lengths"].append(len(ftr["dna_sequence"]))
                    template_genome["num_contigs"] += 1
                    template_genome["dna_size"] += len(ftr["dna_sequence"])

                    result = hashlib.md5(ftr["protein_translation"].encode())
                    md5 = result.hexdigest()
                    result = hashlib.md5(ftr["dna_sequence"].encode())
                    dnamd5 = result.hexdigest()
                    md5_list.append(md5)
                    functions[asv_genus][function] = {"ftrid":ftrid, "probability":1}

                    ##updating the features
                    features[ftrid] = {
                        "aliases": [],
                        "cdss": [ftrid+".CDS"],
                        "functions":[function],
                        "dna_sequence": ftr["dna_sequence"],
                        "dna_sequence_length": len(ftr["dna_sequence"]),
                        "id": ftrid,
                        "location": [[ftrid+".contig", 1, "+", len(ftr["dna_sequence"])]],
                        "md5": dnamd5,
                        "ontology_terms": {},
                        "protein_md5": md5,
                        "protein_translation": ftr["protein_translation"],
                        "protein_translation_length": len(ftr["protein_translation"]),
                        "warnings": []
                    }
                    cdsftr = features[ftrid].copy()
                    del cdsftr["cdss"]
                    cdsftr["id"] = f"{ftrid}.CDS"
                    cdsftr["parent_gene"] = ftrid
                    template_genome["cdss"].append(cdsftr)
                elif function not in genome_functions:  #Don't want to count same function twice in a genome
                    ftrid = functions[asv_genus][function]["ftrid"]
                    functions[asv_genus][function]["probability"] += 1
                
                if "aliases" not in ftr or len(ftr["aliases"]) < 1:  continue
                features[ftrid]["aliases"].append(["gene", f"{info[6]}/{info[0]}.{ftr['aliases'][0][1]}"])
                if function not in functions[asv_genus]:
                    template_genome["features"].append(features[ftrid])
                feature_aliases.setdefault(ftrid, []).append(ftr["aliases"][0][1])
                genome_functions[function] = True
        for func in functions[asv_genus]:
            functions[asv_genus][func]["probability"] /= len(genomes)
            feature_probabilities[functions[asv_genus][func]["ftrid"]] = functions[asv_genus][func]["probability"]
        template_genome["feature_counts"] = {
            "CDS": len(template_genome["features"]),
            "gene": len(template_genome["features"]),
            "non_coding_features": 0,
            "protein_encoding_gene": len(template_genome["features"])
        }                    
        md5_list.sort()
        result = hashlib.md5(";".join(md5_list).encode())
        template_genome["md5"] = result.hexdigest()

        #Writing FASTA
        ofile = open("datacache/Assemblies/"+asv_genus+".fasta", "w")
        for func in functions[asv_genus]:
            ofile.write(">" + functions[asv_genus][func]["ftrid"] + "\n" +features[functions[asv_genus][func]["ftrid"]]["dna_sequence"] + "\n")
        ofile.close()

        print(asv_genus)

        #Saving genome
        util.save(f"genomes/{asv_genus}", template_genome)
        util.save("feature_aliases", feature_aliases)
        util.save("functions", functions)
        util.save("feature_probabilities", feature_probabilities)
# Out:
# 100%|██████████| 478/478 [00:00<00:00, 66298.85it/s]
# Proteiniphilum.1 has already been processed and will be skipped
# midas_g_114992.1 has already been processed and will be skipped
# Sedimentibacter.4 has already been processed and will be skipped
# Alcaligenes.1 has already been processed and will be skipped
# midas_g_9269.1 has already been processed and will be skipped
# midas_g_107376.1 has already been processed and will be skipped
# midas_g_109803.1 has already been processed and will be skipped
# Clostridium_sensu_stricto_7.1 has already been processed and will be skipped
# Syntrophobacter.1 has already been processed and will be skipped
# HN-HF0106.1 has already been processed and will be skipped
# The a1f67bd15d480d23ca73f40a62f815bb is missing in iterativeIDs
# Desulfovibrio.7 has already been processed and will be skipped
# UCG-009.2 has already been processed and will be skipped
# midas_g_7.1 has already been processed and will be skipped
# ...

# %% [markdown]
# # Saving genomes to KBase

# %%
missing_hashes = [asv for asv in match_genomes if asv not in iterativeIDs]
print(f"{len(missing_hashes)}/{len(match_genomes)}")
# for ASV_md5 in match_genomes:
#     if ASV_md5 not in iterativeIDs:
#         print(f"The {ASV_md5} is missing in iterativeIDs")
# Out:
# 75/478

# %%
from datetime import datetime
now = datetime.now()
timestamp = str(datetime.timestamp(now))

#Loading clade genomes to KBase using annotation API, which contains an SDK callback
feature_probabilities = util.load("feature_probabilities")
genomes_nar = 233212
anno = util.kbdevutil.anno_client(native_python_api=True)
# anno.clients["GenomeFileUtil"] = util.kbdevutil.gfu_client()   #!! This is the SDK client
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
# finished = util.load("finished_genomes")
for ASV_md5 in match_genomes:
    if ASV_md5 not in iterativeIDs:
        # print(f"The {ASV_md5} is missing in iterativeIDs")
        continue
    asv_genus = iterativeIDs[ASV_md5]
    if path.exists(f"/Users/andrewfreiburger/Documents/Research/sludge/data/genome_objects/{asv_genus}.gto.json"):
        print(f"{asv_genus} has already been processed and will be skipped")
        continue
    genre = asv_genus.split(".")[0]
    # if asv_genus in finished: continue
    print("Processing:", asv_genus)
    # try:
    genome = util.kbdevutil.load(f"genomes/{asv_genus}")
    # except Exception as e:
    #     print(f"Failed to load {asv_genus}: {e}")
    #     continue
    genome["assembly_ref"] = f"{genomes_nar}/{asv_genus}.assembly"
    genome["source_id"] = asv_genus
    events = [{
        "id": "SSO",
        "event_id":f"RAST:SSO:{timestamp}",
        "description": "RAST annotation of clade genome",
        "ontology_id": "SSO",
        "method": "RAST",
        "method_version": "1.9.5",
        "timestamp": timestamp,
        "ontology_terms": {},
    }]
    for ftr in genome["features"]:
        events[0]["ontology_terms"][ftr["id"]] = [{"term":"SSO:"+ftr["functions"][0],"evidence":{"scores":{"pgprob":feature_probabilities[ftr["id"]]}}}]
    
    output = anno.add_annotation_ontology_events({
        "output_workspace": genomes_nar,
        "events":events,
        "overwrite_matching":True,
        "object":genome,
        "type":"KBaseGenomes.Genome",
        "output_name":asv_genus+".ASV",
        "save":0
    })
    util.save(f"genome_objects/{asv_genus}.gto", output["object"])
    # finished.append(asv_genus)
    # util.save("finished_genomes", finished)
# Out:
# Proteiniphilum.1 has already been processed and will be skipped
# midas_g_114992.1 has already been processed and will be skipped
# Sedimentibacter.4 has already been processed and will be skipped
# Alcaligenes.1 has already been processed and will be skipped
# midas_g_9269.1 has already been processed and will be skipped
# midas_g_107376.1 has already been processed and will be skipped
# midas_g_109803.1 has already been processed and will be skipped
# Clostridium_sensu_stricto_7.1 has already been processed and will be skipped
# Syntrophobacter.1 has already been processed and will be skipped
# HN-HF0106.1 has already been processed and will be skipped
# Desulfovibrio.7 has already been processed and will be skipped
# UCG-009.2 has already been processed and will be skipped
# midas_g_7.1 has already been processed and will be skipped
# Methanomassiliicoccus.1 has already been processed and will be skipped
# Thermovirga.4 has already been processed and will be skipped
# ...

# %% [markdown]
# # Construct the ASV models, gapfilling in auxotrophy and anaerobic glucose minimal media - code cell from KBase copied here for reference

# %%
import requests
import os
import io
import sys
from biokbase.narrative.jobs.appmanager import AppManager
ws_client = biokbase.narrative.clients.get('workspace')
# current_ws = os.environ['KB_WORKSPACE_ID']

genomes_nar = 221042
media_nar = 207617
genomes = ws_client.list_objects({"ids":[genomes_nar],"type":"KBaseGenomes.Genome"})
for genome in genomes[2:]:
    AppManager().run_app(
        "ModelSEEDReconstruction/build_metabolic_models",
        {
            "genome_refs": [f"{genomes_nar}/{genome[1]}"],
            "suffix": ".mdl",
            "run_gapfilling": 1,
            "gapfilling_media_list": [f"{media_nar}/AuxoMedia", f"{media_nar}/PyruateMinimalAnaerobic"],  # This media are good are as a first estimate
            "change_to_complete": 0,
            "atp_safe": 1,
            "forced_atp_list": [],
            "gs_template": "auto",
            "gs_template_ref": None,
            "core_template_ref": None,
            "gapfilling_mode": "Sequential",
            "expression_refs": [],
            "expression_conditions": []
        },
        tag="release",
        version="2.0.0",
        cell_id="c4caea9f-c131-4b17-88e3-19e2b54b655a",
        run_id="9e3a761b-3ca7-4b5a-9197-ae4c858edef2"
    )

# %%
from glob import glob

print([".".join(x.split("/")[-1].split(".")[:2]) for x in glob(f"/Users/andrewfreiburger/Documents/Research/sludge/data/genome_objects/*.gto.json")])
# Out:
# ['Proteiniphilum.5', 'Proteiniphilum.4', 'Pseudomonas.1', 'Christensenellaceae_R-7_group.11', 'Thermovirga.4', 'Christensenellaceae_R-7_group.10', 'midas_g_36215.2', 'midas_g_12.1', 'midas_g_36215.3', 'Azoarcus.2', 'Alcaligenes.2', 'JGI-0000079-D21.1', 'Desulfovibrio.1', 'Leucobacter.1', 'Trichloromonas.1', 'midas_g_91392.1', 'Brevundimonas.2', 'Brevundimonas.3', 'Methanobacterium.4', 'Methanobacterium.5', 'Lentimicrobium.7', 'Pir4_lineage.1', 'Lentimicrobium.6', 'Methanobacterium.17', 'Methanobacterium.16', 'Ca_Cloacimonas.1', 'Pseudarcobacter.1', 'midas_g_94288.1', 'Sedimentibacter.3', 'Sedimentibacter.2', 'Lachnoclostridium.1', 'midas_g_98017.1', 'Bacteroides.2', 'Rhodobacter.1', 'Desulfosporosinus.1', 'Enterococcus.1', 'midas_g_25828.2', 'Methanothrix.1', 'midas_g_156.1', 'midas_g_110683.1', 'midas_g_75908.1', 'Aminivibrio.2', 'Alkaliphilus_oremlandii_OhILAs.1', 'midas_g_4325.2', 'Rhodococcus.1', 'Acinetobacter.1', 'Intestinibacter.1', 'Anaerosalibacter.2', 'Terrisporobacter.2', 
# ...

# %% [markdown]
# # Adding probabilities to ASV models

# %%
from numpy import mean
from json import load
from tqdm import tqdm

feature_probabilities = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/data/feature_probabilities.json", "r"))
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
probability_finished = util.load("probability_finished", default=["Proteiniphilum.1", "midas_g_114992.1", "Sedimentibacter.4", "Alcaligenes.1", "midas_g_9269.1", "midas_g_107376.1", "midas_g_109803.1", "Clostridium_sensu_stricto_7.1", "Syntrophobacter.1", "HN-HF0106.1", "Desulfovibrio.7", "UCG-009.2", "midas_g_7.1", "Methanomassiliicoccus.1", "Thermovirga.4", "midas_g_114252.1", "Christensenellaceae_R-7_group.6", "RBG-16-49-21.1", "midas_g_30443.1", "midas_g_36215.1", "Christensenellaceae_R-7_group.18", "Methanosarcina.4", "Ca_Phosphitivorax.1", "Christensenellaceae_R-7_group.3", "Ca_Caldatribacterium.1", "Dechlorobacter.1", "EBM-39.3", "Methanobacterium.1", "midas_g_399.1", "midas_g_33659.1", "Stenotrophomonas.4", "Brooklawnia.1", "midas_g_49937.1", "midas_g_36215.5", "Acetobacterium.1", "Ruminiclostridium.2", "Romboutsia.1", "Syner-01.2", "Pseudochelatococcus.1", "Dethiobacter.2", "Pseudaminobacter.1", "midas_g_75.1", "Pannonibacter.1", "Proteiniphilum.2", "midas_g_4387.1", "midas_g_515.1", "Ca_Cloacimonas.1", "Lachnoclostridium.4", "midas_g_765.1", "JGI-0000079-D21.1", "Sphingopyxis.5", "midas_g_2178.1", "midas_g_36215.3", "Dethiobacter.1", "Stenotrophomonas.3", "NK4A214_group.1", "Soehngenia.1", "Methanobacterium.4", "Rhodococcus.1", "Pseudomonas.4", "midas_g_19.1", "midas_g_12.1", "Thermobrachium.1", "midas_g_94288.2", "midas_g_119665.1", "Anaerostignum.1", "Sedimentibacter.2", "midas_g_15299.1", "Christensenellaceae_R-7_group.17", "Thiopseudomonas.1", "Proteiniborus.1", "midas_g_52.1", "midas_g_669.5", "Anaerocolumna.2", "midas_g_82137.1", "midas_g_6187.2", "midas_g_110683.1", "Methanobacterium.18", "midas_g_115459.1", "Mesotoga.1", "Methanobacterium.7", "Desulfobulbus.2", "Ca_Cloacimonas.2", "Stenotrophomonas.2", "Enhydrobacter.1", "midas_g_9023.1", "midas_g_76594.1", "Methanobacterium.13", "midas_g_10303.1", "Monoglobus.2", "midas_g_269.1", "Christensenellaceae_R-7_group.5", "Bacillus.1", "Enterococcus.3", "Romboutsia.3", "Syntrophomonas.1", "Syntrophorhabdus.1", "midas_g_4325.2", "Dehalobacterium.1", "Rhodobacter.1", "Taibaiella.1", "Methanobacterium.17", "Afipia.1", "Bosea.2", "Pseudarcobacter.1", "Syner-01.4", "Bosea.1", "midas_g_36376.1", "Caproiciproducens.3", "midas_g_4325.1", "Sulfurospirillum.1", "Desulfovibrio.5", "Hydrogenophaga.1", "midas_g_112760.1", "midas_g_83754.1", "Fermentimonas.1", "midas_g_3595.1", "midas_g_1251.1", "Oscillibacter.1", "Desulfovibrio.3", "Aquamicrobium.1", "midas_g_1981.1", "midas_g_75908.3", "Pelotomaculum.1", "Tissierella.2", "Desulfovibrio.1", "Actinomyces.1", "Smithella.1", "midas_g_1220.1", "Christensenellaceae_R-7_group.10", "midas_g_5574.1", "Hydrogenophaga.2", "midas_g_112829.1", "Bacteroides.2", "Aminivibrio.1", "Desulfobulbus.1", "Mycobacterium.2", "Thermovirga.1", "Anaerovorax.1", "Fonticella.2", "midas_g_4042.1", "Enterococcus.4", "Petrimonas.1", "midas_g_3409.2", "Methanobacterium.10", "Lentimicrobium.3", "Pir4_lineage.1", "Pseudomonas.2", "midas_g_3409.1", "Enterococcus.1", "Bacillus.5", "Fastidiosipila.1", "Clostridium_sensu_stricto_5.1", "Desulfomicrobium.1", "Colidextribacter.1", "Angelakisella.1", "Aquamicrobium.2", "Desulfurispora.1", "Methanobacterium.14", "Caproiciproducens.2", "Paraclostridium.1", "EBM-39.1", "Christensenellaceae_R-7_group.13", "midas_g_97954.1", "Sedimentibacter.1", "Christensenellaceae_R-7_group.7", "Sphaerochaeta.1", "Clostridium_sensu_stricto_13.4", "Rummeliibacillus.1", "Acetobacterium.3", "Desulfovibrio.4", "Anaerovorax.7", "Hyphomonas.1", "Clostridium_sensu_stricto_1.1", "midas_g_249.1", "Sphaerochaeta.2", "Thermovirga.2", "Lentimicrobium.9", "Christensenellaceae_R-7_group.15", "EBM-39.2", "Erysipelothrix.1", "Colidextribacter.3"])

genomes_nar = 221042
models_nar = 233212
no_probs = {}
for asv_md5, genomeIDs in tqdm(match_genomes.items()):
    asvname = iterativeIDs.get(asv_md5, None)
    if asvname == None: continue
    try:
        print(asvname, "trying to load")
        mdlutl = util.msrecon.get_model(f"{asvname}.ASV.mdl", models_nar)
        print(mdlutl.id, "ASV model already exists and is skipped")
        continue
    except Exception as e:
        if "No object with name" not in str(e):
            pass
        else:
            print(e)
    print(asvname, "loading RAST model")
    try:   #TODO:  This needs to be removed when all of the models finish reconstructing in the workspace
        mdlutl = util.msrecon.get_model(f"{asvname}.RAST.mdl", models_nar)
    except Exception as e:
        if "JSONRPCError" not in str(e):
            print(f"{asvname} is not yet built and is skipped")
        print(e)
        # probability_finished.append(asvname)
        # util.save("probability_finished",probability_finished)
        continue
    for rxn in mdlutl.model.reactions:
        # highest_prob = None
        # for gene in rxn.genes:
        #     if gene.id not in feature_probabilities: continue
        #     highest_prob = max(feature_probabilities[gene.id], highest_prob)
        # if highest_prob != None:
            # rxn.probability = highest_prob
        ##TODO consider different mathematical selections of the probabilities to arrive at a single probability
        ### Max is better than mean if the subunits are very different while mean is better if the subunits are similar
        ### worth investigating the frequency of multiple subunits mapped to a single
        rxn_probability = [feature_probabilities[gene.id] for gene in rxn.genes if gene.id in feature_probabilities]
        if len(rxn_probability) == 0:
            no_probs.setdefault(asvname, []).append(rxn.id)
            rxn.probability = 0
        else:
            rxn.probability = max(rxn_probability)
    
    util.msrecon.save_model(mdlutl, models_nar, asvname+".ASV.mdl")
    print(f"{asvname} is completed")
    
    # probability_finished.append(asvname)
    # util.save("probability_finished",probability_finished)

# %% [markdown]
# # Interaction testing for metabolites in models

# %%
from modelseedpy.biochem import from_local
from json import dump

# msdb_path = "/Users/andrewfreiburger/Documents/Research/ModelSEEDDatabase"
msdb_path = "/home/freiburger/Documents/ModelSEEDDatabase"
msdb = from_local(msdb_path)
metabolites = {mID: msdb.get_seed_compound(mID).name for mID in metaboliteIDs}
dump(metabolites, open("/home/freiburger/Documents/MicrobiomeNotebooks/digestor/metabolites.json", 'w'))
metabolites
# Out:
# 1763349992.2262409 INFO: load: /home/freiburger/Documents/ModelSEEDDatabase/Biochemistry/reactions.tsv
# 1763349992.6006596 INFO: load: /home/freiburger/Documents/ModelSEEDDatabase/Biochemistry/compounds.tsv
# 1763349996.9343486 INFO: load: /home/freiburger/Documents/ModelSEEDDatabase/Biochemistry/Structures/Unique_ModelSEED_Structures.txt
# 1763349999.1519167 INFO: load: /home/freiburger/Documents/ModelSEEDDatabase/Biochemistry/Aliases/Unique_ModelSEED_Compound_Aliases.txt
# 1763349999.207545 INFO: load: /home/freiburger/Documents/ModelSEEDDatabase/Biochemistry/Aliases/Unique_ModelSEED_Reaction_Aliases.txt
# 1763349999.296831 INFO: load: /home/freiburger/Documents/ModelSEEDDatabase/Biochemistry/Aliases/Unique_ModelSEED_Reaction_ECs.txt
# {'cpd00254': 'Mg',
#  'cpd00063': 'Ca2+',
#  'cpd00205': 'K+',
#  'cpd00034': 'Zn2+',
#  'cpd00030': 'Mn2+',
#  'cpd00149': 'Co2+',
#  'cpd19013': 'NH4+',
#  'cpd10515': 'Fe+2',
#  'cpd00058': 'Cu2+',
#  'cpd00099': 'Cl-',
#  'cpd00048': 'Sulfate',
# ...

# %%
media_nar = 207617
metabolites = util.msrecon.get_media(f"{media_nar}/Wolfe").mediacompounds
auxo_media = util.msrecon.get_media(f"{media_nar}/AuxoMedia")
anaerobicPyruvate = util.msrecon.get_media(f"{media_nar}/PyruateMinimalAnaerobic")

# %%
from json import load
from numpy import mean

# microbiome_path = "/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor"
microbiome_path = "/home/freiburger/Documents/MicrobiomeNotebooks"
metabolites = load(open(f"{microbiome_path}/digestor/metabolites.json", 'r'))
metaboliteIDs = list(metabolites.keys())

media_nar = 207617
metabolites = util.msrecon.get_media(f"{media_nar}/Wolfe").mediacompounds
auxo_media = util.msrecon.get_media(f"{media_nar}/AuxoMedia")
anaerobicPyruvate = util.msrecon.get_media(f"{media_nar}/PyruateMinimalAnaerobic")
# metabolites
metaboliteIDs = [cpd['id'] for cpd in metabolites] + ["cpd00011", "cpd11640", "cpd01024"]  # experimental media + CO2,H2,CH4

#TODO:  Why is growth only performed for the non-base media and uptake/excretion only performed for the base media?
uptake_phenoset = util.create_phenotypeset_from_compounds(
    metaboliteIDs, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="uptake")
excretion_phenoset = util.create_phenotypeset_from_compounds(
    metaboliteIDs, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="excretion")
agrowth_phenoset = util.create_phenotypeset_from_compounds(
    metaboliteIDs, base_media=anaerobicPyruvate, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="agrowth")
# growth_phenoset = util.create_phenotypeset_from_compounds(
#     metabolites, base_media=gmm_base_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="growth")
phenotypes = {"uptake": uptake_phenoset, "excretion": excretion_phenoset, "agrowth": agrowth_phenoset}

# %%
print(metaboliteIDs)
print(type(agrowth_phenoset))
# Out:
# ['cpd00254', 'cpd00063', 'cpd00205', 'cpd00034', 'cpd00030', 'cpd00149', 'cpd19013', 'cpd10515', 'cpd00058', 'cpd00099', 'cpd00048', 'cpd00009', 'cpd09225', 'cpd11574', 'cpd00131', 'cpd00547', 'cpd00104', 'cpd00393', 'cpd00263', 'cpd00220', 'cpd00218', 'cpd03424', 'cpd00541', 'cpd19112', 'cpd00971', 'cpd00244', 'cpd00443', 'cpd01079', 'cpd03387', 'cpd00305', 'cpd15574', 'cpd00240', 'cpd00067', 'cpd10393', 'cpd00074', 'cpd00011', 'cpd11640']
# <class 'modelseedpy.core.msgrowthphenotypes.MSGrowthPhenotypes'>

# %%
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
phenotype_results = util.load("phenotype_results", default={})

def test_phenotype(pheno_type, phenotype_set, asvname, mdlutl):
    phenotype_results[asvname][pheno_type] = {}
    output = phenotype_set.simulate_phenotypes(
        mdlutl, multiplier=2, add_missing_exchanges=True, save_fluxes=False, gapfill_negatives=False,
        msgapfill=None, test_conditions=None, ignore_experimental_data=True)
    for index, row in output["details"].iterrows():
        phenotype_results[asvname][pheno_type][row["Phenotype"]] = output["data"][row["Phenotype"]]
    util.save("phenotype_results", phenotype_results)

for asv_md5 in match_genomes:
    asvname = iterativeIDs.get(asv_md5, None)
    if asvname is None or asvname in phenotype_results:
        print(f"{asvname} is already computed and is skipped")
        continue
    
    phenotype_results[asvname] = {}
    try:   #TODO:  This needs to be removed when all of the models finish reconstructing in the workspace
        mdlutl = util.msrecon.get_model(f"{asvname}.ASV.mdl", models_nar)
    except Exception as e:
        if "JSONRPCError" not in str(e):
            print(e)
        print(f"{asvname} is not yet built and is skipped")
        # probability_finished.append(asvname)
        # util.save("probability_finished",probability_finished)
        continue
    # mdlutl = util.msrecon.get_model(f"{asvname}.ASV.mdl", models_nar)
    # mdlutl.solver = 'gurobi'
    for pheno_type, phenotype_set in phenotypes.items():
        if pheno_type not in phenotype_results[asvname]:  test_phenotype(pheno_type, phenotype_set, asvname, mdlutl)
# Out:
# Proteiniphilum.1 is already computed and is skipped
# midas_g_114992.1 is already computed and is skipped
# Sedimentibacter.4 is already computed and is skipped
# Alcaligenes.1 is already computed and is skipped
# midas_g_9269.1 is already computed and is skipped
# midas_g_107376.1 is already computed and is skipped
# midas_g_109803.1 is already computed and is skipped
# Clostridium_sensu_stricto_7.1 is already computed and is skipped
# Syntrophobacter.1 is already computed and is skipped
# HN-HF0106.1 is already computed and is skipped
# None is already computed and is skipped
# Desulfovibrio.7 is already computed and is skipped
# UCG-009.2 is already computed and is skipped
# midas_g_7.1 is already computed and is skipped
# None is already computed and is skipped
# None is already computed and is skipped
# None is already computed and is skipped
# Methanomassiliicoccus.1 is already computed and is skipped
# None is already computed and is skipped
# ...

# %% [markdown]
# # Printing interaction matrices

# %%
from json import load
from tqdm import tqdm
from pandas import DataFrame


phenotype_results = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/phenotype_results.json", 'r'))
# print(phenotype_results.keys())
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
base_record = {"ASV": "Name"}
records = {"combined":[base_record], "uptake":[base_record], "excretion":[base_record], "agrowth":[base_record]}
metabolites = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/metabolites.json", 'r'))

for metID, metName in metabolites.items():
    for item in records:
        records[item][0][metID] = metName

value_mapping = {"uptake": "U", "excretion": "E", "agrowth": "A"}
for asv_md5 in tqdm(match_genomes):
    asvname = iterativeIDs.get(asv_md5)
    if asvname not in phenotype_results or phenotype_results[asvname] == {}:  print("No data for ",asvname) ; continue
    # print(asvname)
    new_base = {"ASV": asvname}
    new_record = {"combined": new_base, "uptake": new_base, "excretion": new_base, "agrowth": new_base}
    for metabolite in metabolites:
        value = ""
        for pheno_type in ["uptake", "excretion", "agrowth"]:
            if pheno_type not in phenotype_results[asvname]:
                print(f"Missing {pheno_type} data for ",asvname)
                continue
            if metabolite in phenotype_results[asvname][pheno_type]:
                new_record[pheno_type][metabolite] = phenotype_results[asvname][pheno_type][metabolite]["objective_value"]
                if phenotype_results[asvname][pheno_type][metabolite]["class"] == "P":   value += value_mapping[pheno_type]
            records[pheno_type].append(new_record[pheno_type])
        new_record["combined"][metabolite] = value
        records["combined"].append(new_record["combined"])
#Printing interation matrices
for item in records:
    df = DataFrame.from_records(records[item])
    export_path = f"/Users/andrewfreiburger/Documents/Research/sludge/data/ASV{item}Interactions_classified.csv"
    print(f"Exporting {export_path}")
    df.to_csv(export_path,index=False)
# Out:
# 100%|██████████| 478/478 [00:00<00:00, 16893.56it/s]
# No data for  Proteiniphilum.1
# No data for  midas_g_114992.1
# No data for  midas_g_9269.1
# No data for  midas_g_107376.1
# No data for  midas_g_109803.1
# No data for  Syntrophobacter.1
# No data for  HN-HF0106.1
# No data for  None
# No data for  Desulfovibrio.7
# No data for  UCG-009.2
# No data for  None
# No data for  None
# No data for  None
# No data for  None
# No data for  Thermovirga.4
# No data for  midas_g_114252.1
# No data for  Christensenellaceae_R-7_group.6
# No data for  RBG-16-49-21.1
# No data for  midas_g_30443.1
# No data for  None
# No data for  midas_g_36215.1
# No data for  Christensenellaceae_R-7_group.18
# No data for  Methanosarcina.4
# No data for  None
# No data for  Ca_Phosphitivorax.1
# No data for  Christensenellaceae_R-7_group.3
# No data for  Dechlorobacter.1
# No data for  None
# No data for  None
# No data for  midas_g_36215.5
# No data for  Ruminiclostridium.2
# No data for  Romboutsia.1
# ...

# %%
# %run agoracommutil.py
consolidated_gf_results = util.load("consolidated_gf_results")

phenotype_results = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/phenotype_results.json", 'r'))
# print(phenotype_results.keys())
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
base_record = {"ASV": "Name"}
records = {"combined":[base_record], "uptake":[base_record], "excretion":[base_record], "agrowth":[base_record]}
metabolites = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/metabolites.json", 'r'))

records = {
    "uptake_prob":[{"ASV":"Name"}],
    "excretion_prob":[{"ASV":"Name"}],
    "growth_prob":[{"ASV":"Name"}],
    "uptake_data":[{"ASV":"Name"}],
    "excretion_data":[{"ASV":"Name"}],
    "growth_data":[{"ASV":"Name"}],
}
types = ["uptake","excretion","growth"]
for met in metabolites:
    for item in records:
        records[item][0][met] = metabolite_names[met]
for asvset in asvset_genomes:
    asvname = asvset_names[asvset]
    if asvname not in consolidated_gf_results:
        print("No data for ",asvname)
        continue
    new_record = {}
    for currtype in types:
        new_record[currtype+"_prob"] = {"ASV":asvname}
        new_record[currtype+"_data"] = {"ASV":asvname}
    for metabolite in metabolites:
        for currtype in types:
            if currtype in consolidated_gf_results[asvname]:
                if metabolite in consolidated_gf_results[asvname][currtype] and "new_probability" in consolidated_gf_results[asvname][currtype][metabolite]:
                    new_record[currtype+"_prob"][metabolite] = consolidated_gf_results[asvname][currtype][metabolite]["new_probability"]
                    new_record[currtype+"_data"][metabolite] = str(consolidated_gf_results[asvname][currtype][metabolite]["probrxn"])
                    new_record[currtype+"_data"][metabolite] += "/"+str(consolidated_gf_results[asvname][currtype][metabolite]["otherrxn"])
                    new_record[currtype+"_data"][metabolite] += "/"+str(consolidated_gf_results[asvname][currtype][metabolite]["origgfrxn"])
                    new_record[currtype+"_data"][metabolite] += "/"+str(consolidated_gf_results[asvname][currtype][metabolite]["new_gf"])
                    new_record[currtype+"_data"][metabolite] += "/"+str(consolidated_gf_results[asvname][currtype][metabolite]["gapfill_count"])
                    new_record[currtype+"_data"][metabolite] += "/"+str(consolidated_gf_results[asvname][currtype][metabolite]["reaction_count"])
    for item in records:
        records[item].append(new_record[item])
#Printing interation matrices
for item in records:
    df = pd.DataFrame.from_records(records[item])
    df.to_csv(util.output_dir+"/ASV"+item+"Interactions.csv",index=False)
# Out:
# 1762372579.102895 ERROR: Requested data consolidated_gf_results doesn't exist at /Users/andrewfreiburger/Documents/Research/sludge/Sludge/../data/consolidated_gf_results.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # %run agoracommutil.py
# ----> 2 consolidated_gf_results = util.load("consolidated_gf_results")
#       5 phenotype_results = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/phenotype_results.json", 'r'))
#       6 # print(phenotype_results.keys())
#       7 # asvset_genomes = util.load("asvset_genomes")
#
# File ~/Documents/Research/chenry_utility_module/lib/chenry_utility_module/kbdevutils.py:157, in KBDevUtils.load(self, name, default, kb_type)
#     155     if default == None:
#     156         logger.error("Requested data "+name+" doesn't exist at "+filename)
# ...

# %% [markdown]
# # Loading Sample data

# %%
# from pandas import read_excel
from json import load
asv_asvset = util.load("asv_asvset")
asv_mappings = util.load("asv_mappings")
abundances = load("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/new_abundances.json")
samples = list(abundances.keys())
asv_abundances, asvset_abundances, sample_asvset_abundances, sample_abundanes = {}, {}, {}, {}

for sample, abundances in abundances.items():
    sample_asvset_abundances[sample] = {}
    sample_abundanes[sample] = {"asv_total": 0, "asvset_total": 0, "mapped_asvs_total": 0, "unmapped_asvs_total": 0}
    for asv, abundance in abundances.items():
        # asv_abundances.setdefault(asv, {})
        # asv_abundances[asv][sample] = abundance

        ## TODO: the asv Set abundances need to be summed, and that the asvs are correctly partitioned among the sets
        if asv in asv_asvset and asv_asvset[asv] not in asvset_abundances:
            asvset_abundances[asv_asvset[asv]] = {}
        # for sample in samples:
        # asv_abundances[asv][sample] = abundance
        if asv not in asv_asvset:  continue

        # TODO:  Aren't these just inverses of the sample mapping, in which case only one is necessary?
        asvset_abundances[asv_asvset[asv]].setdefault(sample, 0)
        asvset_abundances[asv_asvset[asv]][sample] += abundance
        
        sample_asvset_abundances[sample].setdefault(asv, 0)
        sample_asvset_abundances[sample][asv] += asvset_abundances[asv_asvset[asv]][sample]
        if asv in asv_set:
            sample_abundanes[sample]["asvset_total"] += asvset_abundances[asv_asvset[asv]][sample]
        else:
            sample_abundanes[sample]["asv_total"] += asv_abundances[asv][sample]

        if asv in asv_mappings:
            sample_abundanes[sample]["mapped_asvs_total"] += asv_abundances[asv][sample]
        else:
            sample_abundanes[sample]["unmapped_asvs_total"] += asv_abundances[asv][sample]


util.save("sample_asvset_abundances",sample_asvset_abundances)
util.save("sample_abundanes",sample_abundanes)
util.save("asv_abundances",asv_abundances)
util.save("asvset_abundances",asvset_abundances)
util.save("samples",samples)
# Out:
# Output files printed to:/Users/chenry/code/notebooks/MicrobiomeNotebooks/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/

# %% [markdown]
# # Now we will generate the sample interaction matrix

# %%
# asv_asvset = util.load("asv_asvset")
metabolites = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/metabolites.json", 'r'))
phenotype_results = util.load("phenotype_results")
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
# asvset_abundances = util.load("asvset_abundances")
# asvset_abundances = util.load("sample_asvset_abundances")
sample_abundanes = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/new_abundances.json", 'r'))
records = {x: [{"Sample":"Name"}] for x in ["uptake_bin", "excretion_bin", "agrowth_bin", "uptake", "excretion", "agrowth"]}
for k in records:
    records[k].append({met: name for met,name in metabolites.items()})

for sample, abundances in sample_abundanes.items():
    new_record = {x: {"Sample":sample} for x in [
        "uptake_bin", "excretion_bin", "agrowth_bin", "uptake", "excretion", "agrowth"]}
    for x in new_record:
        new_record[x].update({met: 0 for met in metabolites})
    
    sample_total = sum(abundances.values())
    for asv_md5, ab in abundances.items():
        asvname = iterativeIDs.get(asv_md5)
        if asvname is None or asvname not in phenotype_results:
            print(f"ASV {asvname} not found in phenotype results")
            continue
        for met in metabolites:
            for pheno_type in ["uptake", "excretion", "agrowth"]:
                if pheno_type not in phenotype_results[asvname]:  continue
                normalized_abundance = sample_abundanes[sample][asv_md5] / sample_total
                if phenotype_results[asvname][pheno_type][met]["class"] == "P":
                    new_record[f"{pheno_type}_bin"][met] += normalized_abundance
                new_record[pheno_type][met] += normalized_abundance * phenotype_results[asvname][pheno_type][met]["objective_value"]
    for item in records:
        records[item].append(new_record[item])
#Printing interation matrices
for item in records:
    df = pd.DataFrame.from_records(records[item])
    export_path = f"/Users/andrewfreiburger/Documents/Research/sludge/data/Sample{item}Interactions.csv"
    print(f"Exporting {export_path}")
    df.to_csv(export_path,index=False)
# Out:
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ASV None not found in phenotype results
# ...

# %% [markdown]
# # Gapfilling phenotype evaluation

# %%
# %run agoracommutil.py
feature_probabilities = util.load("feature_probabilities")
gf_phenotype_results = util.load("new_gf_phenotype_results_", {})
metabolites = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/metabolites.json", 'r'))
phenotype_results = util.load("phenotype_results")
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open("/Users/andrewfreiburger/Documents/Research/sludge/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/iterativeIDs.json", 'r'))
# asvset_abundances = util.load("asvset_abundances")
# asvset_abundances = util.load("sample_asvset_abundances")
sample_abundanes = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/new_abundances.json", 'r'))

genomes_nar = 221042
asv_nar = 233212
# TODO:   Took >140 minutes to run the first ASV

#TODO:  Parallelize this loop to make the progress feasible
prob_func = max # mean
for i, asv in enumerate(match_genomes.keys()):
    asvname = iterativeIDs[asv]
    if asvname in gf_phenotype_results:  continue # or asvname == "Thermus.1":  continue
    mdlutl = util.msrecon.get_model(asvname+".ASV.mdl", asv_nar)
    
    reaction_probabilities = {r.id: [feature_probabilities[g.id] for g in r.genes if g.id in feature_probabilities]
                                for r in mdlutl.model.reactions}
    reaction_probabilities = {rID: prob_func(probs) for rID, probs in reaction_probabilities.items() if len(probs) > 0}
    filters = mdlutl.get_attributes("gf_filter")
    tests = mdlutl.get_atp_tests(core_template=util.msrecon.core_template,
                                atp_media_filename="atp_medias.tsv", recompute=False)
    # TODO:  Why not 'c' as the target gapfill element?
    msgapfill = MSGapfill(mdlutl, [util.msrecon.get_template(mdlutl.model.template_ref)], [], tests,
                            blacklist=[], default_target="bio1", minimum_obj=0.01,
                            base_media=None, base_media_target_element=None)

    #Adding missing transporter for metabolites to gapfilling database
    for cpd in metabolites:
        if f"EX_{cpd}_e0" in msgapfill.gfmodelutl.model.reactions: continue
        transport = msgapfill.gfmodelutl.add_transport_and_exchange_for_metabolite(
            cpd, direction="=", prefix="trans", override=False)

    coefficients = {}
    gf_penalties = msgapfill.gfpkgmgr.getpkg("GapfillingPkg").gapfilling_penalties
    gfrxn = probrxn = otherrxn = 0
    #Defining the objective coefficients for each reaction
    for reaction in msgapfill.gfmodelutl.model.reactions:
        if reaction.id in gf_penalties:
            for direction in ["forward", "reverse"]:
                arrow = ">" if direction == "forward" else "<"
                if direction in gf_penalties[reaction.id]:
                    gfrxn += 1
                    coefficients[f"{arrow}{reaction.id}"] = 1+gf_penalties[reaction.id][direction]
                elif reaction.id in reaction_probabilities:
                    probrxn += 1
                    coefficients[f"{arrow}{reaction.id}"] = 1-reaction_probabilities[reaction.id]
                else:
                    otherrxn += 1
                    coefficients[f"{arrow}{reaction.id}"] = 0.95
        elif reaction.id in reaction_probabilities:
            probrxn += 2
            coef = 1-reaction_probabilities[reaction.id]
            coefficients[">"+reaction.id] = coefficients["<"+reaction.id] = coef
        else:
            otherrxn += 2
            coefficients[">"+reaction.id] = coefficients["<"+reaction.id] = 0.95
    print(asvname, f"GF: {gfrxn}", f"Prob: {probrxn}", f"Other: {otherrxn}")

    msgapfill.prefilter(test_conditions=tests, growth_conditions=[], use_prior_filtering=True, base_filter_only=True)
    backend = msgapfill.gfmodelutl.model.solver
    gf_phenotype_results[asvname] = {}
    for pheno, phenoset  in phenotypes.items():
        print(f"Testing phenotype {pheno}")
        gf_phenotype_results[asvname][pheno] = {}
        msgapfill.gfmodelutl.model.solver = backend
        msgapfill.gfmodelutl.model.solver.update()
        output = phenoset.simulate_phenotypes(
            msgapfill.gfmodelutl, multiplier=2, add_missing_exchanges=True, save_fluxes=False,
            save_reaction_list=True, gapfill_negatives=False, msgapfill=None, test_conditions=None,
            ignore_experimental_data=True, flux_coefficients=coefficients)
        for index, row in output["details"].iterrows():
            if "reactions" not in output["data"][row["Phenotype"]]:  continue
            output["data"][row["Phenotype"]]["average_probability"] = 0
            for rxn in output["data"][row["Phenotype"]]["reactions"]:
                direction = rxn[0:1]
                rxnid = rxn[1:]
                rxn_gf_pen = gf_penalties.get(rxnid, {})
                if rxn_gf_pen == {}:  continue
                if (direction == ">" and "forward" not in rxn_gf_pen) or (direction == "<" and "reverse" not in rxn_gf_pen):
                    if rxnid in reaction_probabilities:
                        output["data"][row["Phenotype"]]["average_probability"] += reaction_probabilities[rxnid]
                    else:
                        output["data"][row["Phenotype"]]["average_probability"] += 0.05
            output["data"][row["Phenotype"]]["average_probability"] = output["data"][row["Phenotype"]]["average_probability"]/len(output["data"][row["Phenotype"]]["reactions"])
            gf_phenotype_results[asvname][pheno][row["Phenotype"]] = output["data"][row["Phenotype"]]
            
    # probability_finished.append(asvname)
    util.save("new_gf_phenotype_results_", gf_phenotype_results)
    # util.save("probability_finished_", probability_finished)
# Out:
# 1763065638.7442975 ERROR: Requested data feature_probabilities doesn't exist at /home/freiburger/Documents/sludge/NewWesternDiet/datacache/feature_probabilities.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # %run agoracommutil.py
# ----> 2 feature_probabilities = util.load("feature_probabilities")
#       3 gf_phenotype_results = util.load("new_gf_phenotype_results_", {})
#       4 metabolites = load(open("/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks/digestor/metabolites.json", 'r'))
#
# File ~/Documents/chenry_utility_module/lib/chenry_utility_module/kbdevutils.py:157, in KBDevUtils.load(self, name, default, kb_type)
#     155     if default == None:
#     156         logger.error("Requested data "+name+" doesn't exist at "+filename)
# ...

# %%
from json import load
from os import path

sludge_path = "/home/freiburger/Documents/sludge"

feature_probabilities = load(open(f"{microbiome_path}/data/feature_probabilities.json", "r"))#  util.load("feature_probabilities")
# gf_phenotype_results = util.load("new_gf_phenotype_results_", {})
metabolites = load(open(f"{microbiome_path}/digestor/metabolites.json", 'r'))
phenotype_results =  load(open(f"{sludge_path}/data/phenotype_results.json", 'r'))
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open(f"{sludge_path}/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open(f"{microbiome_path}/digestor/iterativeIDs.json", 'r'))
# asvset_abundances = util.load("asvset_abundances")
# asvset_abundances = util.load("sample_asvset_abundances")
sample_abundances = load(open(f"{microbiome_path}/digestor/new_abundances.json", 'r'))

genomes_nar = 221042
asv_nar = 233212
prob_func = max #mean
# TODO:   Took >140 minutes to run the first ASV

def calculate_gapfilling(asvname):
    if path.exists(f"gf_phenotype_{asvname}.json"):
        print(f"Gapfilling results for {asvname} already exist, skipping")
        return
    print(f"Running gapfilling for {asvname}")
    mdlutl = util.msrecon.get_model(asvname+".ASV.mdl", asv_nar)
    
    reaction_probabilities = {r.id: [feature_probabilities[g.id] for g in r.genes if g.id in feature_probabilities]
                                for r in mdlutl.model.reactions}
    reaction_probabilities = {rID: prob_func(probs) for rID, probs in reaction_probabilities.items() if len(probs) > 0}
    filters = mdlutl.get_attributes("gf_filter")  #!! Not used?
    tests = mdlutl.get_atp_tests(core_template=util.msrecon.core_template,
                                atp_media_filename="atp_medias.tsv", recompute=False)
    # TODO:  Why not 'c' as the target gapfill element?
    msgapfill = MSGapfill(mdlutl, [util.msrecon.get_template(mdlutl.model.template_ref)], [], tests,
                            blacklist=[], default_target="bio1", minimum_obj=0.01,
                            base_media=None, base_media_target_element=None)

    #Adding missing transporter for metabolites to gapfilling database
    for cpd in metabolites:
        if f"EX_{cpd}_e0" in msgapfill.gfmodelutl.model.reactions: continue
        transport = msgapfill.gfmodelutl.add_transport_and_exchange_for_metabolite(
            cpd, direction="=", prefix="trans", override=False)

    coefficients = {}
    gf_penalties = msgapfill.gfpkgmgr.getpkg("GapfillingPkg").gapfilling_penalties
    gfrxn = probrxn = otherrxn = 0
    #Defining the objective coefficients for each reaction
    for reaction in msgapfill.gfmodelutl.model.reactions:
        if reaction.id in gf_penalties:
            for direction in ["forward", "reverse"]:
                arrow = ">" if direction == "forward" else "<"
                if direction in gf_penalties[reaction.id]:
                    gfrxn += 1
                    coefficients[f"{arrow}{reaction.id}"] = 1+gf_penalties[reaction.id][direction]
                elif reaction.id in reaction_probabilities:
                    probrxn += 1
                    coefficients[f"{arrow}{reaction.id}"] = 1-reaction_probabilities[reaction.id]
                else:
                    otherrxn += 1
                    coefficients[f"{arrow}{reaction.id}"] = 0.95
        elif reaction.id in reaction_probabilities:
            probrxn += 2
            coef = 1-reaction_probabilities[reaction.id]
            coefficients[">"+reaction.id] = coefficients["<"+reaction.id] = coef
        else:
            otherrxn += 2
            coefficients[">"+reaction.id] = coefficients["<"+reaction.id] = 0.95
    print(f"\n{asvname} GF: {gfrxn}", f"Prob: {probrxn}", f"Other: {otherrxn}")

    msgapfill.prefilter(test_conditions=tests, growth_conditions=[], use_prior_filtering=True, base_filter_only=True)
    backend = msgapfill.gfmodelutl.model.solver
    gf_phenotype_results = {asvname: {}}
    for pheno, phenoset  in phenotypes.items():
        print(f"{pheno} in {asvname}")
        gf_phenotype_results[asvname].setdefault(pheno, {})
        msgapfill.gfmodelutl.model.solver = backend
        msgapfill.gfmodelutl.model.solver.update()
        output = phenoset.simulate_phenotypes(
            msgapfill.gfmodelutl, multiplier=2, add_missing_exchanges=True, save_fluxes=False,
            save_reaction_list=True, gapfill_negatives=False, msgapfill=None, test_conditions=None,
            ignore_experimental_data=True, flux_coefficients=coefficients)
        print(f"Completed simulation for {pheno} in {asvname}")
        for index, row in output["details"].iterrows():
            if "reactions" not in output["data"][row["Phenotype"]]:
                gf_phenotype_results[asvname][pheno][row["Phenotype"]] = output["data"][row["Phenotype"]]
                continue
            output["data"][row["Phenotype"]]["average_probability"] = 0
            for rxn in output["data"][row["Phenotype"]]["reactions"]:
                direction = rxn[0:1]
                rxnid = rxn[1:]
                rxn_gf_pen = gf_penalties.get(rxnid, {})
                if rxn_gf_pen == {} or (
                    direction == ">" and "forward" not in rxn_gf_pen
                    ) or (
                        direction == "<" and "reverse" not in rxn_gf_pen
                    ):
                    rxn_prob = reaction_probabilities.get(rxnid, None)
                    if rxn_prob is not None:
                        output["data"][row["Phenotype"]]["average_probability"] += rxn_prob
                    else:
                        output["data"][row["Phenotype"]]["average_probability"] += 0.05
            if len(output["data"][row["Phenotype"]]["reactions"]) == 0:
                print(f"No reactions for {asvname} phenotype {row['Phenotype']}")
                continue
            output["data"][row["Phenotype"]]["average_probability"] /= len(output["data"][row["Phenotype"]]["reactions"])
            gf_phenotype_results[asvname][pheno][row["Phenotype"]] = output["data"][row["Phenotype"]]
            
    # probability_finished.append(asvname)
    dump(gf_phenotype_results, open(f"gf_phenotype_{asvname}.json", 'w'), indent=2)
    print(f"exported gf_phenotype_{asvname}")
    # util.save("probability_finished_", probability_finished)
    

args = [iterativeIDs[asv] for asv in match_genomes.keys() if asv in iterativeIDs]
for arg in args:
    calculate_gapfilling(arg)

#TODO:  Parallelize this loop to make the progress feasible
# from multiprocess import Pool
# from os import cpu_count
# pool = Pool(int(cpu_count()/16))
# args = [iterativeIDs[asv] for asv in match_genomes.keys() if asv in iterativeIDs and iterativeIDs[asv] not in gf_phenotype_results]
# print(args[0])
# pool.map(calculate_gapfilling, args)

# %%
# %run agoracommutil.py
metabolites = util.load("metabolites")
phenotype_results = util.load("phenotype_results")

media_nar = 207617
auxo_media = util.msrecon.get_media(f"{media_nar}/AuxoMedia")
agmm_base_media = util.msrecon.get_media(f"{media_nar}/BaseAnaerobicMM")
gmm_base_media = util.msrecon.get_media(f"{media_nar}/BaseAerobicMM")
uptake_phenoset = util.create_phenotypeset_from_compounds(
    metabolites, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="uptake")

mdlutl = util.msrecon.get_model("Lactobacillus.9.ASV.mdl", media_nar)
filters = mdlutl.get_attributes("gf_filter")
tests = mdlutl.get_atp_tests(core_template=util.msrecon.core_template,
                            atp_media_filename=util.msrecon.module_dir+"/data/atp_medias.tsv", recompute=False)
msgapfill = MSGapfill(
    mdlutl, [util.msrecon.get_template(mdlutl.model.template_ref)], [], tests, blacklist=[],
    default_target="bio1", minimum_obj=0.01, base_media=None, base_media_target_element=None)
msgapfill.prefilter(test_conditions=tests,growth_conditions=[],use_prior_filtering=True)

#Adding missing transporter for metabolites to gapfilling database
supported_metabolites = {}
for cpd in metabolites:
    if f"EX_{cpd}_e0" not in msgapfill.gfmodelutl.model.reactions:
        print(f"Adding transport for {cpd}")
        transport = msgapfill.gfmodelutl.add_transport_and_exchange_for_metabolite(
            cpd, direction="=", prefix="trans", override=False)
        if transport:  supported_metabolites[cpd] = transport.id
    else:
        supported_metabolites[cpd] = 1
util.save("supported_metabolites",supported_metabolites)
msgapfill.gfpkgmgr.getpkg("GapfillingPkg").compute_gapfilling_penalties(exclusion_solution=None,reaction_scores=None)

media_list = []
pheno_list = []
target_hash = {}
for pheno in uptake_phenoset.phenotypes:
    if pheno.id in phenotype_results["Lactobacillus.9"]["uptake"] and phenotype_results["Lactobacillus.9"]["uptake"][pheno.id]["objective_value"] < 0.01:
        if pheno.id in supported_metabolites:
            fullmedia = pheno.build_media()
            fullmedia.id = pheno.id
            for item in fullmedia.mediacompounds:
                if item.id == pheno.id:
                    item.lower_bound = -1000
                    item.upper_bound = -0.01
            pheno_list.append(pheno.id)
            media_list.append(fullmedia)
            #print(phenotype_results["Lactobacillus.9"]["uptake"][pheno.id]["objective"])
            #target_hash[fullmedia] = phenotype_results["Lactobacillus.9"]["uptake"][pheno.id]["objective"]
        else:
            print("No support for ",pheno.id)

#TODO:   Why only Lactobacillus.9 in this phenotype analysis??
phenotype_gf_results = {"Lactobacillus.9": {}}
phenotype_gf_results["Lactobacillus.9"]["uptake"] = msgapfill.run_multi_gapfill(
    media_list, target="bio1", default_minimum_objective=0, binary_check=False, prefilter=False, check_for_growth=True,
    gapfilling_mode="Independent", run_sensitivity_analysis=False, integrate_solutions=False, remove_unneeded_reactions=False)
util.save("phenotype_gf_results",phenotype_gf_results)
# Out:
# Output files printed to:/home/freiburger/Documents/sludge/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# 1763090399.5871282 ERROR: Requested data metabolites doesn't exist at /home/freiburger/Documents/sludge/NewWesternDiet/datacache/metabolites.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().run_line_magic('run', 'agoracommutil.py')
# ----> 2 metabolites = util.load("metabolites")
#       3 phenotype_results = util.load("phenotype_results")
#       5 media_nar = 207617
#
# File ~/Documents/chenry_utility_module/lib/chenry_utility_module/kbdevutils.py:157, in KBDevUtils.load(self, name, default, kb_type)
#     155     if default == None:
#     156         logger.error("Requested data "+name+" doesn't exist at "+filename)
# --> 157         raise(ValueError("Requested data "+name+" doesn't exist at "+filename))
# ...

# %%
import pandas as pd
metabolites = util.load("metabolites")
supported_metabolites = util.load("supported_metabolites")
phenotype_gf_results = util.load("phenotype_gf_results",{})
phenotype_results = util.load("phenotype_results")
asvset_names = util.load("asvset_names")
asvset_genomes = util.load("asvset_genomes")
phenotype_results = util.load("phenotype_results",default={})
phenotype_gf_results = util.load("phenotype_gf_results",default={})

#load media
auxo_media = util.msrecon.get_media("181152/AuxoMedia")
agmm_base_media = util.msrecon.get_media("181152/BaseAnaerobicMM")
gmm_base_media = util.msrecon.get_media("181152/BaseAerobicMM")

#define phenotype
uptake_phenoset = util.create_phenotypeset_from_compounds(
    columns, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="uptake")
excretion_phenoset = util.create_phenotypeset_from_compounds(
    columns, base_media=auxo_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="excretion")
agrowth_phenoset = util.create_phenotypeset_from_compounds(
    columns, base_media=agmm_base_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="growth")
growth_phenoset = util.create_phenotypeset_from_compounds(
    columns, base_media=gmm_base_media, base_uptake=0, base_excretion=1000, global_atom_limits={}, type="growth")

#examine each phenotype
for asvset in asvset_genomes:
    asvname = asvset_names[asvset]
    if asvname in phenotype_results or asvname == "Thermus.1":  continue
    phenotype_gf_results[asvname] = {}
    mdlutl = util.msrecon.get_model(f"{asvname}.ASV.mdl", genomes_nar)
    tests = mdlutl.get_atp_tests(core_template=util.msrecon.core_template,
                                atp_media_filename=util.msrecon.module_dir+"/data/atp_medias.tsv", recompute=False)
    msgapfill = MSGapfill(
        mdlutl, [util.msrecon.get_template(mdlutl.model.template_ref)], [], tests, blacklist=[],
        default_target="bio1", minimum_obj=0.01, base_media=None, base_media_target_element=None)
    msgapfill.prefilter(test_conditions=tests,growth_conditions=[],use_prior_filtering=True)
    #Adding missing transporter for metabolites to gapfilling database
    for cpd in metabolites:
        if "EX_"+cpd+"_e0" in msgapfill.gfmodelutl.model.reactions: continue
        print("Adding transport for ",cpd)
        transport = msgapfill.gfmodelutl.add_transport_and_exchange_for_metabolite(
            cpd, direction="=", prefix="trans", override=False)
    for interaction in ["update", "excretion", "agrowth", "growth"]:
        if interaction not in phenotype_gf_results[asvname]:
            media_list = []
            pheno_list = []
            target_hash = {}
            for pheno in uptake_phenoset.phenotypes:
                if (pheno.id in phenotype_results[asvname][interaction]
                    and phenotype_results[asvname][interaction][pheno.id]["objective_value"] < 0.01
                    and pheno.id in supported_metabolites
                    ):
                    fullmedia = pheno.build_media()
                    pheno_list.append(pheno.id)
                    media_list.append(fullmedia)
                    target_hash[fullmedia] = phenotype_results[asvname][interaction][pheno.id]["objective"]
            phenotype_gf_results[asvname][interaction] = msgapfill.run_multi_gapfill(
                media_list, target_hash=target_hash, default_minimum_objective=0.01, binary_check=False, prefilter=False,
                check_for_growth=True, gapfilling_mode="Independent", run_sensitivity_analysis=False, integrate_solutions=False)
            util.save("henotype_gf_results", phenotype_gf_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ph/360gp1jx5zg7qyqv076prl240000gn/T/ipykernel_75926/2968236246.py in <module>
#       1 import pandas as pd
# ----> 2 metabolites = util.load("metabolites")
#       3 supported_metabolites = util.load("supported_metabolites")
#       4 phenotype_gf_results = util.load("phenotype_gf_results",{})
#       5 phenotype_results = util.load("phenotype_results")
#
# NameError: name 'util' is not defined

# %% [markdown]
# # Consolidating gapfilling phenotype data sets

# %% [markdown]
# # Computing proper gapfill and filtering bad predictions

# %%
# %run agoracommutil.py
from glob import glob
from json import load, dump
# microbiome_path = "/Users/andrewfreiburger/Documents/Research/MicrobiomeNotebooks"
microbiome_path = "/home/freiburger/Documents/MicrobiomeNotebooks"
feature_probabilities = load(open(f"{microbiome_path}/data/feature_probabilities.json", "r"))
asv_nar = 233212
prob_func = max #mean

consolidated_gf_results = {}
for filename in glob("gf_results/*.json"):
    with open(filename, 'r') as f:
        phenotype_gf_results = load(f)
        for asvname in phenotype_gf_results:
            consolidated_gf_results[asvname] = phenotype_gf_results[asvname]
# consolidated_gf_results = load(open("gf_results/consolidated_gf_results.json"))

for asvname in consolidated_gf_results:
    #Getting base model
    mdlutl = util.msrecon.get_model(asvname+".ASV.mdl", asv_nar)
    
    reaction_probabilities = {r.id: [feature_probabilities[g.id] for g in r.genes if g.id in feature_probabilities]
                                for r in mdlutl.model.reactions}
    reaction_probabilities = {rID: prob_func(probs) for rID, probs in reaction_probabilities.items() if len(probs) > 0}
    
    for study in ["uptake","excretion","agrowth"]:
        if study not in consolidated_gf_results[asvname]:  continue
        for phenotype in consolidated_gf_results[asvname][study]:
            if "reactions" not in consolidated_gf_results[asvname][study][phenotype]:   continue
            consolidated_gf_results[asvname][study][phenotype].update({
                "new_probability": 0, "probrxn": 0, "otherrxn": 0, "origgfrxn": 0,
                "new_gf": 0, "new_gf_reactions": []})
            found = False
            for rxn in consolidated_gf_results[asvname][study][phenotype]["reactions"]:
                direction, rxnid = rxn[0:1], rxn[1:]
                if direction not in ["<", ">"]:  print("Unexpected direction in reaction: ", rxn)
                found = True if (rxnid[0:3] == "EX_" and rxnid[3:11] == phenotype) else False
                if rxnid not in mdlutl.model.reactions:
                    consolidated_gf_results[asvname][study][phenotype]["new_gf_reactions"].append(rxn)
                    consolidated_gf_results[asvname][study][phenotype]["new_gf"] += 1
                elif (direction == ">" and (mdlutl.model.reactions.get_by_id(rxnid).upper_bound <= 0)
                      or (direction == "<" and (mdlutl.model.reactions.get_by_id(rxnid).lower_bound >= 0))):
                    consolidated_gf_results[asvname][study][phenotype]["new_gf_reactions"].append(rxn)
                    consolidated_gf_results[asvname][study][phenotype]["new_gf"] += 1
                elif rxnid in reaction_probabilities:
                    consolidated_gf_results[asvname][study][phenotype]["new_probability"] += reaction_probabilities[rxnid]
                    consolidated_gf_results[asvname][study][phenotype]["probrxn"] += 1
                elif rxnid[0:3] != "bio" and rxnid[0:3] != "EX_" and rxnid[0:3] != "DM_" and len(mdlutl.model.reactions.get_by_id(rxnid).genes) == 0:
                    consolidated_gf_results[asvname][study][phenotype]["origgfrxn"] += 1
                else:
                    consolidated_gf_results[asvname][study][phenotype]["otherrxn"] += 1
                    consolidated_gf_results[asvname][study][phenotype]["new_probability"] += 0.05  
            totalrxn = consolidated_gf_results[asvname][study][phenotype]["probrxn"]+consolidated_gf_results[asvname][study][phenotype]["new_gf"]+consolidated_gf_results[asvname][study][phenotype]["otherrxn"]
            consolidated_gf_results[asvname][study][phenotype]["new_probability"] = consolidated_gf_results[asvname][study][phenotype]["new_probability"]/totalrxn

            if not found:
                consolidated_gf_results[asvname][study][phenotype]["original_objective_value"] = consolidated_gf_results[asvname][study][phenotype]["objective_value"]
                consolidated_gf_results[asvname][study][phenotype].update({
                    "objective_value": 0, "class": "N", "positive": False, "new_probability": 0})

dump(consolidated_gf_results, open("gf_results/consolidated_gf_results.json", "w"), indent=3)
# Out:
# 1763347215.3200033 INFO: metabolites 1756
# 1763347235.9266784 INFO: reactions 1963
# 1763347236.0049977 INFO: The current solver interface glpk doesn't support setting the optimality tolerance.
# 1763347236.217121 INFO: Default biomass: [bio1]
# Neither carbon consumption nor oxygen consumption are defined in Brooklawnia.1.RAST.mdl
# 1763347236.5654209 INFO: metabolites 908
# 1763347239.421739 INFO: reactions 816
# 1763347239.4516318 INFO: The current solver interface glpk doesn't support setting the optimality tolerance.
# 1763347239.5360053 INFO: Default biomass: [bio1]
# Neither carbon consumption nor oxygen consumption are defined in Methanomassiliicoccus.1.RAST.mdl
# 1763347240.594016 INFO: metabolites 1510
# 1763347253.4454923 INFO: reactions 1649
# 1763347253.5100656 INFO: The current solver interface glpk doesn't support setting the optimality tolerance.
# 1763347253.6846776 INFO: Default biomass: [bio1]
# ...

# %% [markdown]
# # Printing matrices

# %%
# %run agoracommutil.py
from json import load
consolidated_gf_results = load(open("gf_results/consolidated_gf_results.json", "r"))

sludge_path = "/home/freiburger/Documents/sludge"

feature_probabilities = load(open(f"{microbiome_path}/data/feature_probabilities.json", "r"))#  util.load("feature_probabilities")
# gf_phenotype_results = util.load("new_gf_phenotype_results_", {})
metabolites = load(open(f"{microbiome_path}/digestor/metabolites.json", 'r'))
phenotype_results =  load(open(f"{sludge_path}/data/phenotype_results.json", 'r'))
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open(f"{sludge_path}/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open(f"{microbiome_path}/digestor/iterativeIDs.json", 'r'))
# asvset_abundances = util.load("asvset_abundances")
# asvset_abundances = util.load("sample_asvset_abundances")
sample_abundances = load(open(f"{microbiome_path}/digestor/new_abundances.json", 'r'))

probs = ["uptake_prob", "excretion_prob", "agrowth_prob"]
records = {x: [{"Sample":"Name"}] for x in probs}
for metID, metName in metabolites.items():
    for item in records:
        records[item][0][metID] = metName
for sample, abundances in sample_abundances.items():
    new_record = {x: {"Sample":sample} for x in probs}
    total_abundance = sum(abundances.values())
    for metID in metabolites:
        for item in new_record:
            new_record[item][metID] = 0
    for asv, abundance in abundances.items():
        if asv not in iterativeIDs:
            print(f"ASV {asv} not in iterativeIDs")
            continue
        asvname = iterativeIDs[asv]
        if asvname not in consolidated_gf_results:
            print(f"ASV {asvname} not in consolidated gf results")
            continue
        for metID in metabolites:
            for currtype in ["uptake","excretion","agrowth"]:
                if (currtype not in consolidated_gf_results[asvname] or metID not in consolidated_gf_results[asvname][currtype] 
                    or "new_probability" not in consolidated_gf_results[asvname][currtype][metID]):  continue
                print(f"made it: {asvname} {currtype} {metID}")
                new_prob = consolidated_gf_results[asvname][currtype][metID]["new_probability"]
                new_record[currtype+"_prob"][metID] += (abundance/total_abundance)*new_prob
    for item in records:
        records[item].append(new_record[item])
#Printing interation matrices
for item in records:
    df = pd.DataFrame.from_records(records[item])
    df.to_csv(f"{sludge_path}/Sample{item}Interactions.csv", index=False)
# Out:
# ASV midas_g_83754.1 not in consolidated gf results
# ASV 03a6a6d84a7be4b11b6467c91ca79d57 not in iterativeIDs
# ASV DMER64.1 not in consolidated gf results
# ASV midas_g_36215.2 not in consolidated gf results
# ASV midas_g_36215.3 not in consolidated gf results
# ASV midas_g_36215.4 not in consolidated gf results
# made it: midas_g_36215.5 agrowth cpd00254
# made it: midas_g_36215.5 agrowth cpd00063
# made it: midas_g_36215.5 agrowth cpd00205
# made it: midas_g_36215.5 agrowth cpd00034
# made it: midas_g_36215.5 agrowth cpd00030
# made it: midas_g_36215.5 agrowth cpd00149
# made it: midas_g_36215.5 agrowth cpd19013
# made it: midas_g_36215.5 agrowth cpd10515
# made it: midas_g_36215.5 agrowth cpd00058
# made it: midas_g_36215.5 agrowth cpd00099
# made it: midas_g_36215.5 agrowth cpd00048
# made it: midas_g_36215.5 agrowth cpd00009
# made it: midas_g_36215.5 agrowth cpd09225
# made it: midas_g_36215.5 agrowth cpd11574
# made it: midas_g_36215.5 agrowth cpd00131
# ...

# %% [markdown]
# # Printing ASV data

# %%
from json import load
consolidated_gf_results = load(open("gf_results/consolidated_gf_results.json", "r"))

sludge_path = "/home/freiburger/Documents/sludge"

feature_probabilities = load(open(f"{microbiome_path}/data/feature_probabilities.json", "r"))#  util.load("feature_probabilities")
# gf_phenotype_results = util.load("new_gf_phenotype_results_", {})
metabolites = load(open(f"{microbiome_path}/digestor/metabolites.json", 'r'))
phenotype_results =  load(open(f"{sludge_path}/data/phenotype_results.json", 'r'))
# asvset_genomes = util.load("asvset_genomes")
match_genomes = load(open(f"{sludge_path}/data/match_genomes.json", 'r'))
# asvset_names = util.load("asvset_names")
iterativeIDs = load(open(f"{microbiome_path}/digestor/iterativeIDs.json", 'r'))
# asvset_abundances = util.load("asvset_abundances")
# asvset_abundances = util.load("sample_asvset_abundances")
sample_abundances = load(open(f"{microbiome_path}/digestor/new_abundances.json", 'r'))

types = ["uptake","excretion","agrowth"]
data_types = ["_data", "_prob"]
records = {x+y: [{"ASV":"Name"}] for x in types for y in data_types}
for metID, metName in metabolites.items():
    for item in records:
        records[item][0][metID] = metName
for asv in match_genomes:
    asvname = iterativeIDs.get(asv)
    if asvname is None:
        print("No iterative ID for ",asv)
        continue
    if asvname not in consolidated_gf_results:
        print("No data for ",asvname)
        continue

    new_record = {x+y: {"ASV":asvname} for x in types for y in data_types}
    for metabolite in metabolites:
        for x in types:
            if (x not in consolidated_gf_results[asvname] or metabolite not in consolidated_gf_results[asvname][x]
                or "new_probability" not in consolidated_gf_results[asvname][x][metabolite]): continue
            for y in data_types:
                if y == "_prob":
                    new_record[x+y][metabolite] = consolidated_gf_results[asvname][x][metabolite]["new_probability"]
                else:
                    gf_mets = consolidated_gf_results[asvname][x][metabolite]
                    vals = list(map(str, [gf_mets["probrxn"], gf_mets["otherrxn"], gf_mets["origgfrxn"], gf_mets["new_gf"], gf_mets["gapfill_count"], gf_mets["reaction_count"]]))
                    new_record[x+y][metabolite] = "/".join(vals)
    for item in records:
        records[item].append(new_record[item])
#Printing interation matrices
for item in records:
    df = pd.DataFrame.from_records(records[item])
    df.to_csv(f"{sludge_path}/ASV{item}Interactions.csv",index=False)
# Out:
# No iterative ID for  a1f67bd15d480d23ca73f40a62f815bb
# No iterative ID for  7560406411c714b613d36584ec43158e
# No iterative ID for  299e2f863816a7f03b21144b754c78c6
# No iterative ID for  2ba4d1457701b8d28dbd13027db70a4e
# No iterative ID for  9492bee356a8f7a4a2507cdb4f71df81
# No iterative ID for  08ea1c9b9d368cd6d9bfeb8857e90315
# No iterative ID for  f42aeaf1c13130f1fdfc8bafa43ded29
# No iterative ID for  4182c2b89710fb797b2813108857327a
# No iterative ID for  e2c63d5718cf9ea95828084c3b843443
# No iterative ID for  bc15f0e20879b79188fa5ea9e191428c
# No data for  Dethiobacter.2
# No data for  Pseudaminobacter.1
# No data for  midas_g_75.1
# No data for  Pannonibacter.1
# No data for  Proteiniphilum.2
# No data for  midas_g_4387.1
# No data for  midas_g_515.1
# No data for  Ca_Cloacimonas.1
# No data for  Lachnoclostridium.4
# No data for  midas_g_765.1
# No data for  JGI-0000079-D21.1
# No data for  Sphingopyxis.5
# No data for  midas_g_2178.1
# No data for  midas_g_36215.3
# ...

# %% [markdown]
# # Gapfilling models based on gapfilling simulation results

# %%
from numpy import array
consolidated_gf_results = load(open("gf_results/consolidated_gf_results.json", "r"))
metabolites = load(open(f"{microbiome_path}/digestor/metabolites.json", 'r'))
reactions_to_add = {}

for asvname in consolidated_gf_results:
    if asvname not in finished_models:
        mdlutl = util.msrecon.get_model(asvname+".ASV.mdl",181152)
        types = ["uptake","excretion","growth"]
        reactions_to_add[asvname] = {}
        for currtype in types:
            problist = []
            for metabolite in metabolites:
                if metabolite in consolidated_gf_results[asvname][currtype] and "new_probability" in consolidated_gf_results[asvname][currtype][metabolite]:
                    if consolidated_gf_results[asvname][currtype][metabolite]["new_probability"] > 0:
                        problist.append(consolidated_gf_results[asvname][currtype][metabolite]["new_probability"])
            if len(problist) > 0:
                ave = array(problist).mean()
                stdev = array(problist).std()
                for metabolite in metabolites:
                    if metabolite in consolidated_gf_results[asvname][currtype] and "new_probability" in consolidated_gf_results[asvname][currtype][metabolite]:
                        if consolidated_gf_results[asvname][currtype][metabolite]["new_probability"] > 0:
                            consolidated_gf_results[asvname][currtype][metabolite]["zscore"] = (consolidated_gf_results[asvname][currtype][metabolite]["new_probability"]-ave)/stdev
                            if consolidated_gf_results[asvname][currtype][metabolite]["zscore"] >= -1 and "reactions" in consolidated_gf_results[asvname][currtype][metabolite]:
                                for rxn in consolidated_gf_results[asvname][currtype][metabolite]["reactions"]:
                                    direction = rxn[0:1]
                                    rxnid = rxn[1:]
                                    if rxnid not in mdlutl.model.reactions:
                                        if rxnid not in reactions_to_add[asvname]:
                                            reactions_to_add[asvname][rxnid] = {}
                                        reactions_to_add[asvname][rxnid][direction] = consolidated_gf_results[asvname][currtype][metabolite]["zscore"]
                                    elif direction == ">":
                                        if mdlutl.model.reactions.get_by_id(rxnid).upper_bound <= 0:
                                            if rxnid not in reactions_to_add[asvname]:
                                                reactions_to_add[asvname][rxnid] = {}
                                            reactions_to_add[asvname][rxnid][direction] = consolidated_gf_results[asvname][currtype][metabolite]["zscore"]
                                    elif direction == "<":
                                        if mdlutl.model.reactions.get_by_id(rxnid).lower_bound >= 0:
                                            if rxnid not in reactions_to_add[asvname]:
                                                reactions_to_add[asvname][rxnid] = {}
                                            reactions_to_add[asvname][rxnid][direction] = consolidated_gf_results[asvname][currtype][metabolite]["zscore"]
        util.save("consolidated_gf_results",consolidated_gf_results)
        msgapfill = MSGapfill(
            mdlutl,
            [util.msrecon.get_template(mdlutl.model.template_ref)],
            [],
            [],
            blacklist=[],
            default_target="bio1",
            minimum_obj=0.01,
            base_media=None,
            base_media_target_element=None
        )
        for cpd in metabolites:
            if "EX_"+cpd+"_e0" not in msgapfill.gfmodelutl.model.reactions:
                transport = msgapfill.gfmodelutl.add_transport_and_exchange_for_metabolite(cpd,direction="=",prefix="trans",override=False)
        for rxnid in reactions_to_add[asvname]:
            if rxnid in msgapfill.gfmodel.reactions:
                rxn = msgapfill.gfmodel.reactions.get_by_id(rxnid)
                rxn = rxn.copy()
                mdlutl.model.add_reactions([rxn])
                rxn.upper_bound = 0
                rxn.lower_bound = 0
                if ">" in reactions_to_add[asvname][rxnid]:
                    rxn.upper_bound = 100
                if "<" in reactions_to_add[asvname][rxnid]:
                    rxn.lower_bound = -100
            else:
                print(asvname,"Missing reaction",rxnid,reactions_to_add[asvname][rxnid])
        util.msrecon.save_model(mdlutl,181152,asvname+".ASV.mdl.gf")
util.save("reactions_to_add",reactions_to_add)
# Out:
# Output files printed to:/Users/chenry/code/notebooks/MicrobiomeNotebooks/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/
# 1717567041.530565 INFO: metabolites 1236
# 1717567041.790891 INFO: reactions 1251
# 1717567042.434616 INFO: Default biomass: [bio1]
# 1717567058.6264582 INFO: cpd35610 not found in model!
# 1717567058.627019 CRITICAL: Metabolite cpd35610 not found in model
# 1717567058.643171 INFO: cpd07053 not found in model!
# 1717567058.64384 CRITICAL: Metabolite cpd07053 not found in model
# 1717567058.644323 INFO: cpd04945 not found in model!
# 1717567058.64481 CRITICAL: Metabolite cpd04945 not found in model
# 1717567058.7683961 WARNING: Ignoring reaction 'rxn09180_c0' since it already exists.
# 1717567058.813857 WARNING: Ignoring reaction 'rxn05561_c0' since it already exists.
# 1717567058.969562 INFO: Setting FBAModel computed_attributes to mdlutl attributes
# ...

# %% [markdown]
# # Building and saving community model

# %%
# %run agoracommutil.py
import cobra
sample_asvset_abundances = util.load("sample_asvset_abundances")
sample_abundanes = util.load("sample_abundanes")
asvset_names = util.load("asvset_names")

sample_pairs = [
    ["RC-ABX_-3","RC-ABX_0","RC-ABX_-1.5"],
    ["RC-ABX_0","RC-ABX_3","RC-ABX_1.5"],
    ["RC-ABX_3","RC-ABX_5","RC-ABX_4.0"],
    ["RC-ABX_5","RC-ABX_7","RC-ABX_6.0"],
    ["RC-ABX_8","RC-ABX_11","RC-ABX_9.0"],
    ["RC-ABX_11", "RC-ABX_13","RC-ABX_12.5"]
]
for pair in sample_pairs:
    member_models = []
    member_names = []
    member_abundances = {}
    asv_hash = {}
    for asvset in sample_asvset_abundances[pair[0]]:
        asvname = asvset_names[asvset]
        if asvname not in asv_hash:
            asv_hash[asvname] = sample_asvset_abundances[pair[0]][asvset]
        else:
            asv_hash[asvname] += sample_asvset_abundances[pair[0]][asvset]
    for asvset in sample_asvset_abundances[pair[1]]:
        asvname = asvset_names[asvset]
        if asvname not in asv_hash:
            asv_hash[asvname] = sample_asvset_abundances[pair[1]][asvset]
        else:
            asv_hash[asvname] += sample_asvset_abundances[pair[1]][asvset]
    total_abundance = 0
    for asvname in asv_hash:
        asv_hash[asvname] = asv_hash[asvname]/2
        total_abundance += asv_hash[asvname]
    for asvname in asv_hash:
        asv_hash[asvname] = asv_hash[asvname]/total_abundance
        if asvname != "Thermus.1" and asv_hash[asvname] > 0.01:
            mdlutl = util.msrecon.get_model(asvname+".ASV.mdl.gf",181152)
            member_models.append(mdlutl.model)
            member_names.append(asvname)
            member_abundances[asvname] = asv_hash[asvname]
    comm_model = MSCommunity.build_from_species_models(
        member_models,
        mdlid=pair[2], 
        name=pair[2],
        names=member_names,
        abundances=member_abundances
    )
    cobra.io.save_json_model(comm_model.model, "models/"+pair[2]+'.json')
# Out:
# Output files printed to:/Users/chenry/code/notebooks/MicrobiomeNotebooks/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/
# 1717728513.6705658 INFO: metabolites 1482
# 1717728513.972935 INFO: reactions 1616
# 1717728514.7140841 INFO: Default biomass: [bio1]
# 1717728515.457014 INFO: metabolites 1023
# 1717728515.616482 INFO: reactions 1118
# 1717728516.119099 INFO: Default biomass: [bio1]
# 1717728516.946501 INFO: metabolites 1060
# 1717728517.112511 INFO: reactions 1090
# 1717728518.286844 INFO: Default biomass: [bio1]
# 1717728519.650422 INFO: metabolites 1374
# 1717728519.906087 INFO: reactions 1490
# 1717728520.591357 INFO: Default biomass: [bio1]
# 1717728521.4609768 INFO: metabolites 1058
# 1717728521.622852 INFO: reactions 1169
# 1717728522.142626 INFO: Default biomass: [bio1]
# 1717728522.742181 INFO: metabolites 1286
# 1717728522.9630668 INFO: reactions 1365
# ...

# %%
# %run agoracommutil.py
import cobra
sample_asvset_abundances = util.load("sample_asvset_abundances")
sample_abundanes = util.load("sample_abundanes")
asvset_names = util.load("asvset_names")

sample_pairs = [
    ["RC-ABX_-3","RC-ABX_0","RC-ABX_-1.5"],
    ["RC-ABX_0","RC-ABX_3","RC-ABX_1.5"],
    ["RC-ABX_3","RC-ABX_5","RC-ABX_4.0"],
    ["RC-ABX_5","RC-ABX_7","RC-ABX_6.0"],
    ["RC-ABX_8","RC-ABX_11","RC-ABX_9.0"],
    ["RC-ABX_11", "RC-ABX_13","RC-ABX_12.5"]
]

community_model_data = {}
for pair in sample_pairs:
    member_models = []
    member_names = []
    member_abundances = {}
    asv_hash = {}
    for asvset in sample_asvset_abundances[pair[0]]:
        asvname = asvset_names[asvset]
        if asvname not in asv_hash:
            asv_hash[asvname] = sample_asvset_abundances[pair[0]][asvset]
        else:
            asv_hash[asvname] += sample_asvset_abundances[pair[0]][asvset]
    for asvset in sample_asvset_abundances[pair[1]]:
        asvname = asvset_names[asvset]
        if asvname not in asv_hash:
            asv_hash[asvname] = sample_asvset_abundances[pair[1]][asvset]
        else:
            asv_hash[asvname] += sample_asvset_abundances[pair[1]][asvset]
    total_abundance = 0
    for asvname in asv_hash:
        asv_hash[asvname] = asv_hash[asvname]/2
        total_abundance += asv_hash[asvname]
    for asvname in asv_hash:
        asv_hash[asvname] = asv_hash[asvname]/total_abundance
        if asvname != "Thermus.1" and asv_hash[asvname] > 0.01:
            member_names.append(asvname)
            member_abundances[asvname] = asv_hash[asvname]
    community_model_data[pair[2]] = {
        "names":member_names,
        "abundances":member_abundances
    }
    util.save("community_model_data",community_model_data)
# Out:
# Output files printed to:/Users/chenry/code/notebooks/MicrobiomeNotebooks/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/

# %% [markdown]
# # Simulating community model in each condition

# %%
# %run agoracommutil.py
procid = 0
metabolites = util.load("metabolites")
metabolomics_data = util.load("metabolomics_data")
feature_probabilities = util.load("feature_probabilities")
community_model_data = util.load("community_model_data")
from optlang.symbolics import Zero, add
import cobra

complete_media = util.msrecon.get_media("KBaseMedia/Complete")

model_list = ["RC-ABX_-1.5","RC-ABX_1.5","RC-ABX_4.0","RC-ABX_6.0","RC-ABX_9.0","RC-ABX_12.5"]
output = {}
rxn_record_hash = {}
records = [
    {"id":"max_growth"},
    {"id":"carbon_uptake"},
    {"id":"flux fitting objective"},
    {"id":"minimum probability objective"},
]
for modelid in model_list:
    output[modelid] = {}
    base_model = cobra.io.load_json_model("models/"+modelid+'.json')
    current_comm_model = MSCommunity(
        model=base_model,
        names=community_model_data[modelid]["names"]
    )
    #loadedmodel.solver = 'gurobi'
    dipeptide_exchanges = [
        "EX_cpd11591_e0",
        "EX_cpd11589_e0",
        "EX_cpd15605_e0",
        "EX_cpd11588_e0",
        "EX_cpd11583_e0",
        "EX_cpd11580_e0",
        "EX_cpd11593_e0",
        "EX_cpd11585_e0",
        "EX_cpd11586_e0",
        "EX_cpd15604_e0",
        "EX_cpd11581_e0",
        "EX_cpd01017_e0",
        "EX_cpd11590_e0",
        "EX_cpd11592_e0",
        "EX_cpd11584_e0",
        "EX_cpd00731_e0",
        "EX_cpd15603_e0",
        "EX_cpd11587_e0",
        "EX_cpd11582_e0",
        "EX_cpd15606_e0",
        "EX_cpd03424_e0",
        "EX_cpd00423_e0",
        "EX_cpd00080_e0",
        "EX_cpd02233_e0",
        "EX_cpd00355_e0",
        "EX_cpd00235_e0",
        "EX_cpd00079_e0",
        "EX_cpd01912_e0"
    ]
    reaction_probabilities = {}
    for rxn in base_model.reactions:
        highest_prob = None
        for gene in rxn.genes:
            if gene.id in feature_probabilities:
                if highest_prob == None or feature_probabilities[gene.id] > highest_prob:
                    highest_prob = feature_probabilities[gene.id]
        if highest_prob != None:
            rxn.probability = highest_prob
            reaction_probabilities[rxn.id] = highest_prob
        elif rxn.id[0:3] != "bio" and rxn.id[0:3] != "EX_" and rxn.id[0:3] != "DM_" and len(rxn.genes) == 0:
            reaction_probabilities[rxn.id] = 0
        else:
            reaction_probabilities[rxn.id] = 0.05
    min_prob = 0.05
    prob_exp = 1
    ex_weight = 1
    kinetics_coef = 750
    mdlutl = current_comm_model.mdlutl
    pkgmgr = MSPackageManager.get_pkg_mgr(mdlutl)
    #Setting media
    pkgmgr.getpkg("KBaseMediaPkg").build_package(complete_media)
    #Adding commkinetic constraints
    pkgmgr.getpkg("CommKineticPkg").build_package(kinetics_coef, current_comm_model)
    #Adding elemental uptake constraints
    pkgmgr.getpkg("ElementUptakePkg").build_package({"C": 300})
    for rxn in base_model.reactions:
        if "EX_" == rxn.id[0:3]:
            currrxn = current_comm_model.model.reactions.get_by_id(rxn.id)
            if rxn.id in dipeptide_exchanges:
                currrxn.lower_bound = 0
                currrxn.upper_bound = 0
            else:
                if currrxn.lower_bound < 0:
                    currrxn.lower_bound = -1000
                if currrxn.upper_bound > 0:
                    currrxn.upper_bound = 1000
    currrxn = current_comm_model.model.reactions.get_by_id("EX_cpd00007_e0")
    currrxn.lower_bound = -20
    #Maximize biomass production
    mdlutl.model.objective = mdlutl.model.problem.Objective(Zero, direction="max")
    mdlutl.model.objective.set_linear_coefficients({mdlutl.model.reactions.bio1.forward_variable: 1})
    first_solution = mdlutl.model.optimize()
    output[modelid]["max_growth"] = first_solution.objective_value
    output[modelid]["carbon_uptake"] = pkgmgr.getpkg("ElementUptakePkg").variables["elements"]["C"].primal
    records[0][modelid] = output[modelid]["max_growth"]
    records[1][modelid] = output[modelid]["carbon_uptake"]
    print(modelid+" growth:", output[modelid]["max_growth"])
    print(modelid+"carbon uptake:",output[modelid]["carbon_uptake"])
    
    with open(util.output_dir+"/"+modelid+"-growth.lp", "w") as out:
        out.write(str(mdlutl.model.solver))

    if str(output[modelid]["max_growth"]) == "nan":
        print("Skipping condition due to infeasibility", modelid)
        continue
    #Constraining to 70% of community biomass
    pkgmgr.getpkg("ObjConstPkg").build_package(output[modelid]["max_growth"] * 0.5, None)
    #Creating minimal probability objective
    coef = {}
    flux_fitting_target = {}
    for rxn in base_model.reactions:
        if "rxn" == rxn.id[0:3]:
            probability = reaction_probabilities[rxn.id]
            currrxn = mdlutl.model.reactions.get_by_id(rxn.id)
            coef.update(
                {
                    currrxn.forward_variable: max(
                        min_prob, (1 - float(probability) ** prob_exp)
                    )
                }
            )
            coef.update(
                {
                    currrxn.reverse_variable: max(
                        min_prob, (1 - float(probability) ** prob_exp)
                    )
                }
            )
        elif "EX_" == rxn.id[0:3]:
            currrxn = mdlutl.model.reactions.get_by_id(rxn.id)
            if rxn.id[3:11] in metabolomics_data:
                flux_fitting_target[rxn.id] = -1*output[modelid]["max_growth"]*metabolomics_data[rxn.id[3:11]][modelid]
            coef.update({currrxn.forward_variable: ex_weight})
            coef.update({currrxn.reverse_variable: ex_weight})

    #Solving the LP
    #pkgmgr.getpkg("FluxFittingPkg").build_package({
    #    "target_flux": flux_fitting_target,
    #    "totalflux": 0,
    #    "set_objective": 1,
    #    "default_rescaling": 0.1,
    #    "rescale_vfit_by_flux": True
    #})
    stuck_reactions = {}
    for iteration in range(1,11,1):
        print("Iteration",iteration)
        for rxn in flux_fitting_target:
            if rxn in stuck_reactions:
                continue
            currrxn = mdlutl.model.reactions.get_by_id(rxn)
            starting_point = first_solution.fluxes[rxn]
            distance = abs(flux_fitting_target[rxn] - starting_point)
            original_upper = currrxn.upper_bound
            original_lower = currrxn.lower_bound
            if starting_point > flux_fitting_target[rxn]:
                if starting_point-iteration*distance/10 < currrxn.upper_bound:
                    currrxn.lower_bound = starting_point-iteration*distance/10
                    currrxn.upper_bound = starting_point-iteration*distance/10
                else:
                    currrxn.upper_bound = starting_point-iteration*distance/10
                    currrxn.lower_bound = starting_point-iteration*distance/10
            else:
                if flux_fitting_target[rxn]-(10-iteration)*distance/10 < currrxn.upper_bound:
                    currrxn.lower_bound = flux_fitting_target[rxn]-(10-iteration)*distance/10
                    currrxn.upper_bound = flux_fitting_target[rxn]-(10-iteration)*distance/10
                else:
                    currrxn.upper_bound = flux_fitting_target[rxn]-(10-iteration)*distance/10
                    currrxn.lower_bound = flux_fitting_target[rxn]-(10-iteration)*distance/10
            solution = mdlutl.model.optimize()
            if solution.status != "optimal":
                print("Stuck",rxn,starting_point,flux_fitting_target[rxn],original_upper)
                stuck_reactions[rxn] = 1
                if original_upper >= currrxn.lower_bound:
                    currrxn.upper_bound = original_upper
                    currrxn.lower_bound = original_lower
                else:
                    currrxn.lower_bound = original_lower
                    currrxn.upper_bound = original_upper
    for rxn in flux_fitting_target:
        currrxn = mdlutl.model.reactions.get_by_id(rxn)
        print(currrxn.id,currrxn.lower_bound,currrxn.upper_bound)
    #solution = mdlutl.model.optimize()
    #output[modelid]["flux fitting objective"] = solution.objective_value
    
    #with open(util.output_dir+"/"+modelid+"-fitting.lp", "w") as out:
    #    out.write(str(mdlutl.model.solver))

    #records[2][modelid] = output[modelid]["flux fitting objective"]
    #for rxn in flux_fitting_target:
    #    currrxn = current_comm_model.model.reactions.get_by_id(rxn)
    #    if solution.fluxes[rxn] > 0:
    #        currrxn.upper_bound = solution.fluxes[rxn]
    #        currrxn.lower_bound = solution.fluxes[rxn]
    #    elif solution.fluxes[rxn] < 0:
    #        currrxn.lower_bound = solution.fluxes[rxn]
    #        currrxn.upper_bound = solution.fluxes[rxn]
    #Setting probability minimization objective
    mdlutl.model.objective = mdlutl.model.problem.Objective(Zero, direction="min")
    mdlutl.model.objective.set_linear_coefficients(coef)
    solution = mdlutl.model.optimize()
    if solution.status != "optimal":
        while solution.status != "optimal":
            print("Infeasible: reducing objective constraint",0.9*mdlutl.pkgmgr.getpkg("ObjConstPkg").constraints["objc"]["1"].lb)
            mdlutl.pkgmgr.getpkg("ObjConstPkg").constraints["objc"]["1"].lb = 0.9*mdlutl.pkgmgr.getpkg("ObjConstPkg").constraints["objc"]["1"].lb
            solution = mdlutl.model.optimize()
    output[modelid]["minimum probability objective"] = solution.objective_value
    
    with open(util.output_dir+"/"+modelid+"-final.lp", "w") as out:
        out.write(str(mdlutl.model.solver))

    records[3][modelid] = output[modelid]["minimum probability objective"]
    output[modelid]["solution"] = {}
    for rxn in mdlutl.model.reactions:
        if rxn.id not in rxn_record_hash:
            rxn_record_hash[rxn.id] = {
                "id":rxn.id,
            }
            for item in model_list:
                rxn_record_hash[rxn.id][item] = None
            records.append(rxn_record_hash[rxn.id])
        rxn_record_hash[rxn.id][modelid] = solution.fluxes[rxn.id]
        output[modelid]["solution"][rxn.id] = solution.fluxes[rxn.id]
    util.save("CommunityFluxSolution2", output)
    df = DataFrame.from_records(records)
    df.to_csv(util.output_dir+"/CommunityFluxSolution2.csv")
# Out:
# python version 3.9.13
# KBBaseModules 0.0.1
# 1717943223.189431 INFO: Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 1717943223.190034 INFO: NumExpr defaulting to 8 threads.
# modelseedpy 0.3.3
# cobrakbase 0.3.1
# Output files printed to:/Users/chenry/code/notebooks/MicrobiomeNotebooks/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/
# 1717943251.4168189 INFO: Making atp hydrolysis reaction for species: Lactobacillus.3
# 1717943252.043584 INFO: Making atp hydrolysis reaction for species: Merdibacter.1
# 1717943252.363841 INFO: Making atp hydrolysis reaction for species: Nosocomiicoccus.1
# 1717943252.677865 INFO: Making atp hydrolysis reaction for species: Staphylococcus.3
# 1717943253.002086 INFO: Making atp hydrolysis reaction for species: Turicibacter.1
# 1717943253.3384378 INFO: Making atp hydrolysis reaction for species: Lactobacillus.1
# ...

# %% [markdown]
# # Printing ASV results for analysis

# %%
# %run agoracommutil.py
community_model_data = util.load("community_model_data")
CommunityFluxSolution = util.load("CommunityFluxSolution2")
sample_asvset_abundances = util.load("sample_asvset_abundances")
sample_abundanes = util.load("sample_abundanes")
metabolomics_data = util.load("metabolomics_data")
asvset_names = util.load("asvset_names")
metabolites = util.load("metabolites")
metabolite_names = util.load("metabolite_names")

sample_pairs = {
    "RC-ABX_-1.5" : ["RC-ABX_-3","RC-ABX_0"],
    "RC-ABX_1.5" : ["RC-ABX_0","RC-ABX_3"],
    "RC-ABX_4.0" : ["RC-ABX_3","RC-ABX_5"],
    "RC-ABX_6.0" : ["RC-ABX_5","RC-ABX_7"],
    "RC-ABX_9.0" : ["RC-ABX_8","RC-ABX_11"],
    "RC-ABX_12.5" : ["RC-ABX_11", "RC-ABX_13"]
}

asvnames_asvset = {}
for asvset in asvset_names:
    asvnames_asvset[asvset_names[asvset]] = asvset

sample_interval_exchanges = {}#[Sample interval][metabolite] = Flux
asv_sampleinterval_flux_profiles = {}#[ASV][Sample][Reaction] = Flux
asv_sample_flux_profiles = {}#[ASV][Sample][Reaction] = Flux
rxn_data_hash = {}
asv_biomass = {}
asv_rescaled_biomass = {}
biomasses = {}
for modelid in CommunityFluxSolution:
    sample_interval_exchanges[modelid] = {}
    asv_sample_flux_profiles[modelid] = {}
    base_model = cobra.io.load_json_model("models/"+modelid+'.json')
    for rxnobj in base_model.reactions:
        if rxnobj.id[0:3] == "rxn": 
            (baseid,compartment) = rxnobj.id.split("_")
            if baseid not in rxn_data_hash:
                rxn_data_hash[baseid] = {
                    "id":baseid,
                    "equation":str(rxnobj),
                    "name":rxnobj.name,
                    "obj":rxnobj
                } 
    solution = CommunityFluxSolution[modelid]["solution"]
    biomasses[modelid] = solution["bio1"]
    asv_biomass[modelid] = {}
    asv_rescaled_biomass[modelid] = {}
    for asvname in community_model_data[modelid]["abundances"]:
        asv_biomass[modelid][asvname] = community_model_data[modelid]["abundances"][asvname]*biomasses[modelid]
        asvset = asvnames_asvset[asvname]
        for sample in sample_pairs[modelid]:
            if asvset in sample_asvset_abundances[sample]:
                asv_rescaled_biomass[modelid][asvname] = community_model_data[modelid]["abundances"][asvname]*sample_asvset_abundances[sample][asvset]
            else:
                asv_rescaled_biomass[modelid][asvname] = 0
    for rxn in solution:
        if rxn[0:3] == "EX_":
            sample_interval_exchanges[modelid][rxn[3:11]] = solution[rxn]
        elif rxn[0:3] == "rxn":
            (baseid,compartment) = rxn.split("_")
            if compartment[0:1] == "c":
                index = int(rxn.split("_")[1][1:])
                asvname = community_model_data[modelid]["names"][index-1]
                asvset = asvnames_asvset[asvname]
                if asvname not in asv_sampleinterval_flux_profiles:
                    asv_sampleinterval_flux_profiles[asvname] = {}
                if modelid not in asv_sampleinterval_flux_profiles[asvname]:
                    asv_sampleinterval_flux_profiles[asvname][modelid] = {}
                if asvname not in asv_sample_flux_profiles:
                    asv_sample_flux_profiles[asvname] = {}
                for sample in sample_pairs[modelid]:
                    if sample not in asv_sample_flux_profiles[asvname]:
                        asv_sample_flux_profiles[asvname][sample] = {}
                    if asvset in sample_asvset_abundances[sample]:
                        asv_sample_flux_profiles[asvname][sample][baseid] = solution[rxn]/community_model_data[modelid]["abundances"][asvname]*sample_asvset_abundances[sample][asvset]
                    else:
                        asv_sample_flux_profiles[asvname][sample][baseid] = 0
                asv_sampleinterval_flux_profiles[asvname][modelid][baseid] = solution[rxn]

#Computing metabolite interactions and printing dataframe of scaled ASV flux profiles per sample inteval
record_hash = {}
records = []
asv_metabolite_interactions = {}
for asvname in asv_sampleinterval_flux_profiles:
    asv_metabolite_interactions[asvname] = {}
    for modelid in asv_sampleinterval_flux_profiles[asvname]:
        asv_metabolite_interactions[asvname][modelid] = {}
        for rxn in asv_sampleinterval_flux_profiles[asvname][modelid]:
            if rxn not in record_hash:
                record_hash[rxn] = {
                    "id":rxn,
                    "equation":rxn_data_hash[rxn]["equation"],
                    "name":rxn_data_hash[rxn]["name"]
                }
                records.append(record_hash[rxn])
            for met in rxn_data_hash[rxn]["obj"].metabolites:
                if met.id.split("_")[1] == "e0" and met.id.split("_")[0] in metabolites:
                    if met.id not in asv_metabolite_interactions[asvname][modelid]:
                        asv_metabolite_interactions[asvname][modelid][met.id.split("_")[0]] = 0
                    if rxn_data_hash[rxn]["obj"].metabolites[met] < 0:
                        #This transport is a consumption reaction; consumption should be negative
                        asv_metabolite_interactions[asvname][modelid][met.id.split("_")[0]] += -1*asv_sampleinterval_flux_profiles[asvname][modelid][rxn]
                    else:
                        #This transport is a excretion reaction; excretion should be positive
                        asv_metabolite_interactions[asvname][modelid][met.id.split("_")[0]] += asv_sampleinterval_flux_profiles[asvname][modelid][rxn]       
            record_hash[rxn][asvname+"_"+modelid] = asv_sampleinterval_flux_profiles[asvname][modelid][rxn]/asv_biomass[modelid][asvname] 
df = pd.DataFrame.from_records(records)
df.to_csv(util.output_dir+"/ASVFluxes.csv",index=False)

#Printing ASV metabolite interation matrix
record_hash = {}
records = []
for asvname in asv_metabolite_interactions:
    new_record = {"ASV":asvname}
    for modelid in asv_metabolite_interactions[asvname]:
        for met in asv_metabolite_interactions[asvname][modelid]:
            new_record[met+"_"+modelid] = asv_metabolite_interactions[asvname][modelid][met]
    for met in metabolites:
        total = 0
        count = 0
        for modelid in asv_metabolite_interactions[asvname]:
            if met in asv_metabolite_interactions[asvname][modelid]:
                total += asv_metabolite_interactions[asvname][modelid][met]
                count += 1
        if count > 0:
            new_record[met+"_ave"] = total/count
    records.append(new_record)
df = pd.DataFrame.from_records(records)
df.to_csv(util.output_dir+"/ASVMetaboliteInteractions.csv",index=False)

#Printing dataframe of Sample metabolite interactions per interval and per sample
record_hash = {}
records = [{"Interval":"Name"}]
for met in metabolites:
    records[0][met] = metabolite_names[met]
for modelid in sample_interval_exchanges:
    new_record = {"Interval":modelid}
    for metabolite in sample_interval_exchanges[modelid]:
        new_record[metabolite] = sample_interval_exchanges[modelid][metabolite]
    records.append(new_record)
df = pd.DataFrame.from_records(records)
df.to_csv(util.output_dir+"/SampleIntervalMetaboliteInterations.csv",index=False)
# Out:
# Output files printed to:/Users/chenry/code/notebooks/MicrobiomeNotebooks/NewWesternDiet/nboutput when using KBDevUtils.output_dir
# ModelSEED: /Users/chenry/code//kb_sdk/run_local/workdir/tmp/

# %% [markdown]
# # Printing Sample results from analysis
